# %%
"""
Scrape all the mesh terms from the pubmed papers
"""
import math
import urllib

from bs4 import BeautifulSoup
from contextlib import closing
import cxutils as cx
import matplotlib.pyplot as plt
from requests import get
from requests.exceptions import RequestException

# Too old, need to figure out a replacement
# from wordcloud import WordCloud
# %matplotlib qt

# %%
# List of paper titles found on pubmed after removing FPs.
titles = cx.read_lines(os.path.join('search_results', 'pubmed', 'with-constraints.txt'))

base_url = 'https://www.ncbi.nlm.nih.gov/pubmed/?term='

# %%
# The base page with search results. This is uncleaned (false positives).
# scrape_page = 'https://www.ncbi.nlm.nih.gov/pubmed/?term=(mimic-ii+OR+mimic-iii+OR+mimicii+OR+mimiciii+OR+mimic-2+OR+mimic-3+OR+mimic2+OR+mimic3)+AND+(physionet+OR+icu+OR+%E2%80%9Cintensive+care%E2%80%9D+OR+%E2%80%9Ccritical+care%E2%80%9D)'

# %%
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None

def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200
            and content_type is not None
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors.
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
all_mesh_terms = []
all_publication_types = []

for title in titles:
    print('Title: {}'.format(title))
    search_url = base_url + urllib.parse.quote_plus(title)
    content = simple_get(search_url)
    html = BeautifulSoup(content, 'html.parser')
    # The publication type. May be present.
    pub_item = html.find('a', alsec='ptyp')
    if pub_item:
        all_publication_types.append(pub_item.text)
    # The mesh items
    mesh_items = html.find_all('a', alsec='mesh')
    print('Number of items: {}'.format(len(mesh_items)))
    for item in mesh_items:
        all_mesh_terms.append(item.text)
# Out:
# Title: prediction model of in-hospital mortality in intensive care unit patients with heart failure: machine learning-based, retrospective analysis of the mimic-iii database
# Number of items: 0
# Title: effects of circadian heart rate variation on short-term and long-term mortality in intensive care unit patients: a retrospective cohort study based on mimic-ii database
# Number of items: 0
# Title: the impact of transthoracic echocardiography on the short-term prognosis of elderly patients in the intensive care unit: a retrospective analysis based on the mimic-iii database
# Number of items: 0
# Title: a comprehensive evaluation for the prediction of mortality in intensive care units with lstm networks: patients with cardiovascular disease
# Number of items: 0
# Title: risk factors for death and their predictive value on diabetic kidney disease patients in intensive care unit based on mimic-iii database
# Number of items: 0
# Title: outcomes for patients with sepsis following admission to the intensive care unit based on health insurance status: a study from the medical information mart for intensive care-iii (mimic-iii) database
# Number of items: 0
# Title: dynamic survival prediction in intensive care units from heterogeneous time series without the need for variable selection or curation
# Number of items: 0
# Title: mortality prediction in intensive care units with the super icu learner algorithm (sicula): a population-based study
# Number of items: 0
# Title: prevalence and nature of financial considerations documented in narrative clinical records in intensive care units
# Number of items: 0
# Title: development and validation of a prognostic nomogram for myocardial infarction patients in intensive care units: a retrospective cohort study
# Number of items: 0
# Title: relationship between "1-hour serum lactate" level and 30-day mortality in critical care patients in intensive care unit
# Number of items: 0
# Title: mortality prediction in intensive care units (icus) using a deep rule-based fuzzy classifier
# Number of items: 0
# Title: diuretic strategies in patients with resistance to loop-diuretics in the intensive care unit: a retrospective study from the mimic-iii database
# Number of items: 0
# Title: five novel clinical phenotypes for critically ill patients with mechanical ventilation in intensive care units: a retrospective and multi database study
# Number of items: 0
# Title: association between body mass index and short-term mortality in patients with intra-abdominal infections: a retrospective, single-centre cohort study using the medical information mart for intensive care database
# Number of items: 0
# Title: mortality prediction in cerebral hemorrhage patients using machine learning algorithms in intensive care units
# Number of items: 0
# Title: prognostic value of red blood cell distribution width in acute pancreatitis patients admitted to intensive care units: an analysis of a publicly accessible clinical database mimic ii
# Number of items: 0
# Title: a novel artificial intelligence based intensive care unit monitoring system: using physiological waveforms to identify sepsis
# Number of items: 0
# Title: the weekend effect for stroke patients admitted to intensive care: a retrospective cohort analysis
# Number of items: 0
# Title: critical transitions in intensive care units: a sepsis case study
# Number of items: 0
# Title: analysis of diseases distribution in medical information mart for intensive care iii database
# Number of items: 0
# Title: value of early critical care transthoracic echocardiography for patients undergoing mechanical ventilation: a retrospective study
# Number of items: 0
# Title: association between comorbid chronic obstructive pulmonary disease and prognosis of patients admitted to the intensive care unit for non-copd reasons: a retrospective cohort study
# Number of items: 0
# Title: monocyte/lymphocyte ratio as a predictor of 30-day mortality and adverse events in critically ill patients: analysis of the mimic-iii database
# Number of items: 0
# Title: cardio-pulmonary-renal interactions in icu patients. role of mechanical ventilation, venous congestion and perfusion deficit on worsening of renal function: insights from the mimic-iii database
# Number of items: 0
# Title: development and internal validation of a nomogram to predict mortality during the icu stay of thoracic fracture patients without neurological compromise: an analysis of the mimic-iii clinical database
# Number of items: 0
# Title: novel data imputation for multiple types of missing data in intensive care units
# Number of items: 0
# Title: improved survival of cancer patients admitted to the intensive care unit between 2002 and 2011 at a u.s. teaching hospital
# Number of items: 0
# Title: association of prescription opioid use on mortality and hospital length of stay in the intensive care unit
# Number of items: 0
# Title: prolonged elevated heart rate and 90-day survival in acutely ill patients: data from the mimic-iii database
# Number of items: 0
# Title: the impact of statin use prior to intensive care unit admission on critically ill patients with sepsis
# Number of items: 0
# Title: analysis of adult disease characteristics and mortality on mimic-iii
# Number of items: 0
# Title: a nomogram to predict in-hospital mortality for post-gastrointestinal resection surgery patients in intensive care units: a retrospective cohort study
# Number of items: 0
# Title: elevated lactate dehydrogenase levels display a poor prognostic factor for non-hodgkin's lymphoma in intensive care unit: an analysis of the mimic-iii database combined with external validation
# Number of items: 0
# Title: nocturnal mean arterial pressure rising is associated with mortality in the intensive care unit: a retrospective cohort study
# Number of items: 0
# Title: predicting lab values for gastrointestinal bleeding patients in the intensive care unit: a comparative study on the impact of comorbidities and medications
# Number of items: 0
# Title: performance of intensive care unit severity scoring systems across different ethnicities in the usa: a retrospective observational study
# Number of items: 0
# Title: the effect of ventilator-associated pneumonia on the prognosis of intensive care unit patients within 90 days and 180 days
# Number of items: 0
# Title: prediction of hypotension events with physiologic vital sign signatures in the intensive care unit
# Number of items: 0
# Title: impact and predictive value of time-dependent acute physiology and chronic health evaluation ii score on death risk in patients with severe stroke: data analysis based on mimic-iii
# Number of items: 0
# Title: mimic-iii, a freely accessible critical care database
# Number of items: 0
# Title: iseeu: visually interpretable deep learning for mortality prediction inside the icu
# Number of items: 0
# Title: using explainable machine learning to improve intensive care unit alarm systems
# Number of items: 0
# Title: the association between four scoring systems and 30-day mortality among intensive care patients with sepsis: a cohort study
# Number of items: 0
# Title: early hospital mortality prediction of intensive care unit patients using an ensemble learning approach
# Number of items: 0
# Title: atrial fibrillation detection during sepsis: study on mimic iii icu data
# Number of items: 0
# Title: a novel model to label delirium in an intensive care unit from clinician actions
# Number of items: 0
# Title: a machine learning sepsis prediction algorithm for intended intensive care unit use (navoy sepsis): proof-of-concept study
# Number of items: 0
# Title: central venous pressure measurement is associated with improved outcomes in septic patients: an analysis of the mimic-iii database
# Number of items: 0
# Title: a long short-term memory ensemble approach for improving the outcome prediction in intensive care unit
# Number of items: 0
# Title: machine learning outperforms existing clinical scoring tools in the prediction of postoperative atrial fibrillation during intensive care unit admission after cardiac surgery
# Number of items: 0
# Title: novel method of atrial fibrillation case identification and burden estimation using the mimic-iii electronic health data set
# Number of items: 0
# Title: sentiment analysis based on the nursing notes on in-hospital 28-day mortality of sepsis patients utilizing the mimic-iii database
# Number of items: 0
# Title: use of electronic health record data to evaluate the impact of race on 30-day mortality in patients admitted to the intensive care unit
# Number of items: 0
# Title: risk factors for pulmonary embolism in icu patients: a retrospective cohort study from the mimic-iii database
# Number of items: 0
# Title: introduction of critical care database based on specialized information systems: a model of critical care medicine database in large level iii grade a hospital
# Number of items: 0
# Title: an empirical evaluation of deep learning for icd-9 code assignment using mimic-iii clinical notes
# Number of items: 0
# Title: combination of static and temporal data analysis to predict mortality and readmission in the intensive care
# Number of items: 0
# Title: the obesity paradox in icu patients
# Number of items: 0
# Title: nomogram to predict the risk of acute kidney injury in patients with diabetic ketoacidosis: an analysis of the mimic-iii database
# Number of items: 0
# Title: early prediction of acute kidney injury following icu admission using a multivariate panel of physiological measurements
# Number of items: 0
# Title: effect of early hyperoxemia on mortality in mechanically ventilated septic shock patients according to sepsis-3 criteria: analysis of the mimic-iii database
# Number of items: 0
# Title: a nomogram to predict in-hospital mortality of neonates admitted to the intensive care unit
# Number of items: 0
# Title: association of sex with clinical outcome in critically ill sepsis patients: a retrospective analysis of the large clinical database mimic-iii
# Number of items: 0
# Title: prediction of early unplanned intensive care unit readmission in a uk tertiary care hospital: a cross-sectional machine learning approach
# Number of items: 0
# Title: application of support vector machine in predicting in-hospital mortality risk of patients with acute kidney injury in icu
# Number of items: 0
# Title: nomogram to predict the risk of septic acute kidney injury in the first 24 h of admission: an analysis of intensive care unit data
# Number of items: 0
# Title: identifying risk factors for pressure injury in adult critical care patients
# Number of items: 0
# Title: lower serum chloride concentrations are associated with increased risk of mortality in critically ill cirrhotic patients: an analysis of the mimic-iii database
# Number of items: 0
# Title: multiparameter intelligent monitoring in intensive care ii: a public-access intensive care unit database
# Number of items: 0
# Title: analysis and prediction of unplanned intensive care unit readmission using recurrent neural networks with long short-term memory
# Number of items: 0
# Title: using machine learning methods to predict in-hospital mortality of sepsis patients in the icu
# Number of items: 0
# Title: an explainable machine learning algorithm for risk factor analysis of in-hospital mortality in sepsis survivors with icu readmission
# Number of items: 0
# Title: machine learning for the prediction of volume responsiveness in patients with oliguric acute kidney injury in critical care
# Number of items: 0
# Title: lactate indices as predictors of in-hospital mortality or 90-day survival after admission to an intensive care unit in unselected critically ill patients
# Number of items: 0
# Title: performance of d-dimer for predicting sepsis mortality in the intensive care unit
# Number of items: 0
# Title: a novel switching state-space model for post-icu mortality prediction and survival analysis
# Number of items: 0
# Title: data-driven curation process for describing the blood glucose management in the intensive care unit
# Number of items: 0
# Title: neural network predicts need for red blood cell transfusion for patients with acute gastrointestinal bleeding admitted to the intensive care unit
# Number of items: 0
# Title: examination of electrolyte replacements in the icu utilizing mimic-iii dataset demonstrates redundant replacement patterns
# Number of items: 0
# Title: the critical care data exchange format: a proposed flexible data standard for combining clinical and high-frequency physiologic data in critical care
# Number of items: 0
# Title: an interpretable intensive care unit mortality risk calculator
# Number of items: 0
# Title: prognostic nomogram for acute pancreatitis patients: an analysis of publicly electronic healthcare records in intensive care unit
# Number of items: 0
# Title: dexmedetomidine versus midazolam and propofol for sedation in critically ill patients: mining the medical information mart for intensive care data
# Number of items: 0
# Title: sentiment in nursing notes as an indicator of out-of-hospital mortality in intensive care patients
# Number of items: 0
# Title: incorporating real-world evidence into the development of patient blood glucose prediction algorithms for the icu
# Number of items: 0
# Title: serum anion gap at admission predicts all-cause mortality in critically ill patients with cerebral infarction: evidence from the mimic-iii database
# Number of items: 0
# Title: the association between neutrophil-to-lymphocyte count ratio and mortality in septic patients: a retrospective analysis of the mimic-iii database
# Number of items: 0
# Title: serum anion gap predicts all-cause mortality in critically ill patients with acute kidney injury: analysis of the mimic-iii database
# Number of items: 0
# Title: accessing the public mimic-ii intensive care relational database for clinical research
# Number of items: 0
# Title: heuristics to determine ventilation times of icu patients from the mimic-ii database
# Number of items: 0
# Title: red blood cell distribution width predicts long-term outcomes in sepsis patients admitted to the intensive care unit
# Number of items: 0
# Title: multitask prediction of organ dysfunction in the intensive care unit using sequential subnetwork routing
# Number of items: 0
# Title: withholding or withdrawing invasive interventions may not accelerate time to death among dying icu patients
# Number of items: 0
# Title: reducing false asystole alarms in intensive care
# Number of items: 0
# Title: a machine learning-based model for 1-year mortality prediction in patients admitted to an intensive care unit with a diagnosis of sepsis
# Number of items: 0
# Title: health status monitoring for icu patients based on locally weighted principal component analysis
# Number of items: 0
# Title: predicting risk for trauma patients using static and dynamic information from the mimic iii database
# Number of items: 0
# Title: leveraging a critical care database: selective serotonin reuptake inhibitor use prior to icu admission is associated with increased hospital mortality
# Number of items: 0
# Title: adaptive online monitoring for icu patients by combining just-in-time learning and principal component analysis
# Number of items: 0
# Title: development of acute kidney injury prognostic model for critically ill patients based on mimic-iii database
# Number of items: 0
# Title: machine learning prediction models for mechanically ventilated patients: analyses of the mimic-iii database
# Number of items: 0
# Title: predicting icu readmission using grouped physiological and medication trends
# Number of items: 0
# Title: machine learning for real-time prediction of complications in critical care: a retrospective study
# Number of items: 0
# Title: clinical data mining by exploring public mimic-ii intensive care database
# Number of items: 0
# Title: effects of etomidate use in icu patients on ventilator therapy: a study of 12,526 patients in an open database from a single center
# Number of items: 0
# Title: long-term mortality predictors of icu fungaemia
# Number of items: 0
# Title: fluid-limiting treatment strategies among sepsis patients in the icu: a retrospective causal analysis
# Number of items: 0
# Title: red blood cell distribution width and neutrophil to lymphocyte ratio are associated with outcomes of adult subarachnoid haemorrhage patients admitted to intensive care unit
# Number of items: 0
# Title: early prediction of acute kidney injury in critical care setting using clinical notes and structured multivariate physiological measurements
# Number of items: 0
# Title: big data and machine learning in critical care: opportunities for collaborative research
# Number of items: 0
# Title: an attention based deep learning model of clinical events in the intensive care unit
# Number of items: 0
# Title: arterial oxygen pressure targets in critically ill patients: analysis of a large icu database
# Number of items: 0
# Title: towards a decision support tool for intensive care discharge: machine learning algorithm development using electronic healthcare data from mimic-iii and bristol, uk
# Number of items: 0
# Title: the relationship between the serum anion gap and all-cause mortality in acute pancreatitis: an analysis of the mimic-iii database
# Number of items: 0
# Title: development of a nomogram to predict 28-day mortality of patients with sepsis-induced coagulopathy: an analysis of the mimic-iii database
# Number of items: 0
# Title: predicting open wound mortality in the icu using machine learning
# Number of items: 0
# Title: n-gram support vector machines for scalable procedure and diagnosis classification, with applications to clinical free text data from the intensive care unit
# Number of items: 0
# Title: predictive value of ionized calcium in critically ill patients: an analysis of a large clinical database mimic ii
# Number of items: 0
# Title: a clinically practical and interpretable deep model for icu mortality prediction with external validation
# Number of items: 0
# Title: predicting the incidence of pressure ulcers in the intensive care unit using machine learning
# Number of items: 0
# Title: interpretability of time-series deep learning models: a study in cardiovascular patients admitted to intensive care unit
# Number of items: 0
# Title: septic shock prediction for icu patients via coupled hmm walking on sequential contrast patterns
# Number of items: 0
# Title: predicting hyperlactatemia in the mimic ii database
# Number of items: 0
# Title: predicting in-hospital mortality of patients with acute kidney injury in the icu using random forest model
# Number of items: 0
# Title: using demographic and time series physiological features to classify sepsis in the intensive care unit
# Number of items: 0
# Title: the incidence and outcome of severe hyperlactatemia in critically ill patients
# Number of items: 0
# Title: predicting severe clinical events by learning about life-saving actions and outcomes using distant supervision
# Number of items: 0
# Title: a deep learning backcasting approach to the electrolyte, metabolite, and acid-base parameters that predict risk in icu patients
# Number of items: 0
# Title: association between early central venous pressure measurement and mortality in patients with sepsis: a data analysis of mimic-iii database
# Number of items: 0
# Title: using information theory to identify redundancy in common laboratory tests in the intensive care unit
# Number of items: 0
# Title: comparison of four scoring systems for predicting icu mortality in patients with sepsis
# Number of items: 0
# Title: lower short- and long-term mortality associated with overweight and obesity in a large cohort study of adult intensive care unit patients
# Number of items: 0
# Title: umls mapping and word embeddings for icd code assignment using the mimic-iii intensive care database
# Number of items: 0
# Title: predicting hypotension in the icu using noninvasive physiological signals
# Number of items: 0
# Title: open-access mimic-ii database for intensive care research
# Number of items: 0
# Title: a web-based data visualization tool for the mimic-ii database
# Number of items: 0
# Title: hypotension risk prediction via sequential contrast patterns of icu blood pressure
# Number of items: 0
# Title: customization of a severity of illness score using local electronic medical record data
# Number of items: 0
# Title: fuzzy modeling to predict severely depressed left ventricular ejection fraction following admission to the intensive care unit using clinical physiology
# Number of items: 0
# Title: do the types and routes of proton pump inhibitor treatments affect <i>clostridium difficile</i> in icu patients? a retrospective cohort study
# Number of items: 0
# Title: a new prediction model for assessing the clinical outcomes of icu patients with community-acquired pneumonia: a decision tree analysis
# Number of items: 0
# Title: robust monitoring of hypovolemia in intensive care patients using photoplethysmogram signals
# Number of items: 0
# Title: unpacking prevalence and dichotomy in quick sequential organ failure assessment and systemic inflammatory response syndrome parameters: observational data-driven approach backed by sepsis pathophysiology
# Number of items: 0
# Title: machine learning predicts mortality in septic patients using only routinely available abg variables: a multi-centre evaluation
# Number of items: 0
# Title: association between obstructive sleep apnea and reduced mortality in critically ill patients: a propensity score-based analysis
# Number of items: 0
# Title: inhaled beta2-agonists increase in-hospital mortality in icu patients with heart failure
# Number of items: 0
# Title: mortality prediction for patients with acute respiratory distress syndrome based on machine learning: a population-based study
# Number of items: 0
# Title: prediction of an acute hypotensive episode during an icu hospitalization with a super learner machine-learning algorithm
# Number of items: 0
# Title: predictive modeling of bacterial infections and antibiotic therapy needs in critically ill adults
# Number of items: 0
# Title: benchmarking deep learning architectures for predicting readmission to the icu and describing patients-at-risk
# Number of items: 0
# Title: developing and verifying a multivariate model to predict the survival probability after coronary artery bypass grafting in patients with coronary atherosclerosis based on the mimic-iii database
# Number of items: 0
# Title: a retrospective cohort study on the association between red cell distribution width and all-cause mortality of patients with cholecystitis at icu admission
# Number of items: 0
# Title: improvement of apache ii score system for disease severity based on xgboost algorithm
# Number of items: 0
# Title: atrial fibrillation detection in icu patients: a pilot study on mimic iii data<sup>.</sup>
# Number of items: 0
# Title: m
# Number of items: 0
# Title: development and validation of a novel blending machine learning model for hospital mortality prediction in icu patients with sepsis
# Number of items: 0
# Title: prediction of septic shock onset in icu by instantaneous monitoring of vital signs<sup>.</sup>
# Number of items: 0
# Title: effect of ondansetron on reducing icu mortality in patients with acute kidney injury
# Number of items: 0
# Title: predicting prolonged length of icu stay through machine learning
# Number of items: 0
# Title: democratizing ehr analyses with fiddle: a flexible data-driven preprocessing pipeline for structured clinical data
# Number of items: 0
# Title: association of thiamine use with outcomes in patients with sepsis and alcohol use disorder: an analysis of the mimic-iii database
# Number of items: 0
# Title: admission hyperglycemia predicts long-term mortality in critically ill patients with subarachnoid hemorrhage: a retrospective analysis of the mimic-iii database
# Number of items: 0
# Title: mean arterial pressure and mortality in patients with distributive shock: a retrospective analysis of the mimic-iii database
# Number of items: 0
# Title: understanding the complexity of sepsis mortality prediction via rule discovery and analysis: a pilot study
# Number of items: 0
# Title: efficient and sparse feature selection for biomedical text classification via the elastic net: application to icu risk stratification from nursing notes
# Number of items: 0
# Title: admission white blood cell count predicts post-discharge mortality in patients with acute aortic dissection: data from the mimic-iii database
# Number of items: 0
# Title: impact of sex on use of low tidal volume ventilation in invasively ventilated icu patients-a mediation analysis using two observational cohorts
# Number of items: 0
# Title: overweight is associated with better one-year survival in elderly patients after cardiac surgery: a retrospective analysis of the mimic-iii database
# Number of items: 0
# Title: predicting 30-days mortality for mimic-iii patients with sepsis-3: a machine learning approach using xgboost
# Number of items: 0
# Title: admission oxygen saturation and all-cause in-hospital mortality in acute myocardial infarction patients: data from the mimic-iii database
# Number of items: 0
# Title: toward optimal heparin dosing by comparing multiple machine learning methods: retrospective study
# Number of items: 0
# Title: the association between autoimmune disease and 30-day mortality among sepsis icu patients: a cohort study
# Number of items: 0
# Title: unstructured clinical notes within the 24 hours since admission predict short, mid & long-term mortality in adult icu patients
# Number of items: 0
# Title: acute kidney injury detection using refined and physiological-feature augmented urine output
# Number of items: 0
# Title: favorable outcomes of anticoagulation with unfractioned heparin in sepsis-induced coagulopathy: a retrospective analysis of mimic-iii database
# Number of items: 0
# Title: sentiment analysis for necessary preview of 30-day mortality in sepsis patients and the control strategies
# Number of items: 0
# Title: association between normalized lactate load and mortality in patients with septic shock: an analysis of the mimic-iii database
# Number of items: 0
# Title: minimum heart rate and mortality in critically ill myocardial infarction patients: an analysis of the mimic-iii database
# Number of items: 0
# Title: fuzzy risk stratification and risk assessment model for clinical monitoring in the icu
# Number of items: 0
# Title: icuarm-an icu clinical decision support system using association rule mining
# Number of items: 0
# Title: hyperchloremia in critically ill patients: association with outcomes and prediction using electronic health record data
# Number of items: 0
# Title: clinical characteristics of aortic aneurysm in mimic-iii
# Number of items: 0
# Title: prevalence and mortality of hypochloremia among patients suffering from coronary artery disease and congestive heart failure: an analysis of patients in cin-i and mimic-iii databases
# Number of items: 0
# Title: does diabetes mellitus increase the short- and long-term mortality in patients with critical acute myocardial infarction? results from american mimic-iii and chinese cin cohorts
# Number of items: 0
# Title: early lactate measurement is associated with better outcomes in septic patients with an elevated serum lactate level
# Number of items: 0
# Title: a deep learning solution to recommend laboratory reduction strategies in icu
# Number of items: 0
# Title: scalable predictive analysis in critically ill patients using a visual open data analysis platform
# Number of items: 0
# Title: effect of hypoproteinemia on the mortality of sepsis patients in the icu: a retrospective cohort study
# Number of items: 0
# Title: an artificial neural networks model for early predicting in-hospital mortality in acute pancreatitis in mimic-iii
# Number of items: 0
# Title: a machine learning-based algorithm for the prediction of intensive care unit delirium (pride): retrospective study
# Number of items: 0
# Title: using demographic factors and comorbidities to develop a predictive model for icu mortality in patients with acute exacerbation copd
# Number of items: 0
# Title: prediction models for aki in icu: a comparative study
# Number of items: 0
# Title: the association of coagulation indicators with in-hospital mortality and 1-year mortality of patients with sepsis at icu admissions: a retrospective cohort study
# Number of items: 0
# Title: an exploratory data quality analysis of time series physiologic signals using a large-scale intensive care unit database
# Number of items: 0
# Title: calcium supplementation improves clinical outcome in intensive care unit patients: a propensity score matched analysis of a large clinical database mimic-ii
# Number of items: 0
# Title: association between comorbid asthma and prognosis of critically ill patients with severe sepsis: a cohort study
# Number of items: 0
# Title: red blood cell distribution width is associated with mortality risk in patients with acute respiratory distress syndrome based on the berlin definition: a propensity score matched cohort study
# Number of items: 0
# Title: mapping patient trajectories using longitudinal extraction and deep learning in the mimic-iii critical care database
# Number of items: 0
# Title: supervised machine learning for the early prediction of acute respiratory distress syndrome (ards)
# Number of items: 0
# Title: development and validation of a clinical prediction model for sleep disorders in the icu: a retrospective cohort study
# Number of items: 0
# Title: false ventricular tachycardia alarm suppression in the icu based on the discrete wavelet transform in the ecg signal
# Number of items: 0
# Title: transthoracic echocardiography and mortality in sepsis: analysis of the mimic-iii database
# Number of items: 0
# Title: data-driven discovery of a novel sepsis pre-shock state predicts impending septic shock in the icu
# Number of items: 0
# Title: prognostic accuracy of the serum lactate level, the sofa score and the qsofa score for mortality among adults with sepsis
# Number of items: 0
# Title: association between furosemide administration and outcomes in critically ill patients with acute kidney injury
# Number of items: 0
# Title: reproducing a prospective clinical study as a computational retrospective study in mimic-ii
# Number of items: 0
# Title: a novel nomogram for predicting survival in patients with severe acute pancreatitis: an analysis based on the large mimic-iii clinical database
# Number of items: 0
# Title: short- and medium-term survival of critically ill patients with solid cancer admitted to the intensive care unit
# Number of items: 0
# Title: predicting in-hospital mortality of icu patients: the physionet/computing in cardiology challenge 2012
# Number of items: 0
# Title: a visualisation and extraction tool for time series in the mimic iii database
# Number of items: 0
# Title: positive fluid balance is associated with increased in-hospital mortality in patients with intracerebral hemorrhage
# Number of items: 0
# Title: factors associated with outcomes of septic shock patients receiving high dose noradrenaline according to three primary infection sites
# Number of items: 0
# Title: association between base excess and mortality in patients with congestive heart failure
# Number of items: 0
# Title: a decision support method for prehospital emergency care based on ranking the importance of physiological variables
# Number of items: 0
# Title: prediction of weaning from mechanical ventilation using convolutional neural networks
# Number of items: 0
# Title: novel criteria to classify ards severity using a machine learning approach
# Number of items: 0
# Title: deep-learning-based survival prediction of patients in coronary care units
# Number of items: 0
# Title: prediction of acute hypotensive episodes by means of neural network multi-models
# Number of items: 0
# Title: machine learning prediction models for mortality in intensive care unit patients with lactic acidosis
# Number of items: 0
# Title: an artificial intelligence tool to predict fluid requirement in the intensive care unit: a proof-of-concept study
# Number of items: 0
# Title: association between blood eosinophils and mortality in critically ill patients with acute exacerbation of chronic obstructive pulmonary disease: a retrospective cohort study
# Number of items: 0
# Title: association of serum total and ionized calcium with all-cause mortality incritically ill patients with acute kidney injury
# Number of items: 0
# Title: the prognostic value of modified nutric score for patients in cardiothoracic surgery recovery unit: a retrospective cohort study
# Number of items: 0
# Title: adaptive template matching of photoplethysmogram pulses to detect motion artefact
# Number of items: 0
# Title: assessing the readability of freely available icu notes
# Number of items: 0
# Title: predicting acute kidney injury in critically ill patients using comorbid conditions utilizing machine learning
# Number of items: 0
# Title: a deep learning approach for sepsis monitoring via severity score estimation
# Number of items: 0
# Title: designing optimal mortality risk prediction scores that preserve clinical knowledge
# Number of items: 0
# Title: text processing for detection of fungal ocular involvement in critical care patients: cross-sectional study
# Number of items: 0
# Title: the mimic code repository: enabling reproducibility in critical care research
# Number of items: 0
# Title: investigating resuscitation code assignment in the intensive care unit using structured and unstructured data
# Number of items: 0
# Title: mimic ii: a massive temporal icu patient database to support research in intelligent patient monitoring
# Number of items: 0
# Title: prognostic value of blood urea nitrogen/creatinine ratio for septic shock: an analysis of the mimic-iii clinical database
# Number of items: 0
# Title: a machine learning method for acute hypotensive episodes prediction using only non-invasive parameters
# Number of items: 0
# Title: utilization of echocardiography during septic shock was associated with a decreased 28-day mortality: a propensity score-matched analysis of the mimic-iii database
# Number of items: 0
# Title: mechanical power of ventilation is associated with mortality in critically ill patients: an analysis of patients in two observational cohorts
# Number of items: 0
# Title: association of acidemia with short-term mortality of acute myocardial infarction: a retrospective study base on mimic-iii database
# Number of items: 0
# Title: establishment and validation of the predictive model for the in-hospital death in patients with sepsis
# Number of items: 0
# Title: enhancing prediction models for one-year mortality in patients with acute myocardial infarction and post myocardial infarction syndrome
# Number of items: 0
# Title: estimation of baseline serum creatinine with machine learning
# Number of items: 0
# Title: development and validation of a risk stratification model for predicting the mortality of acute kidney injury in critical care patients
# Number of items: 0
# Title: real-time prognosis of icu physiological data streams
# Number of items: 0
# Title: predicting future occurrence of acute hypotensive episodes using noninvasive and invasive features
# Number of items: 0
# Title: prediction of in-hospital mortality of <i>clostriodiodes difficile</i> infection using critical care database: a big data-driven, machine learning approach
# Number of items: 0
# Title: early hospital mortality prediction using vital signals
# Number of items: 0
# Title: oasis +: leveraging machine learning to improve the prognostic accuracy of oasis severity score for predicting in-hospital mortality
# Number of items: 0
# Title: establishment of a prognostic model for patients with sepsis based on sofa: a retrospective cohort study
# Number of items: 0
# Title: association between the neutrophil percentage-to-albumin ratio and outcomes in cardiac intensive care unit patients
# Number of items: 0
# Title: ecg signal quality during arrhythmia and its application to false alarm reduction
# Number of items: 0
# Title: peeking into a black box, the fairness and generalizability of a mimic-iii benchmarking model
# Number of items: 0
# Title: red blood cell distribution width provides additional prognostic value beyond severity scores in adult critical illness
# Number of items: 0
# Title: feature explanations in recurrent neural networks for predicting risk of mortality in intensive care patients
# Number of items: 0
# Title: application of machine learning to predict acute kidney disease in patients with sepsis associated acute kidney injury
# Number of items: 0
# Title: impact of pulmonary arterial hypertension on systemic inflammation, cardiac injury and hemodynamics in sepsis: a retrospective study from mimic-iii
# Number of items: 0
# Title: association of hyperchloremia with all-cause mortality in patients admitted to the surgical intensive care unit: a retrospective cohort study
# Number of items: 0
# Title: utilizing imbalanced electronic health records to predict acute kidney injury by ensemble learning and time series model
# Number of items: 0
# Title: performance of sequential organ failure assessment and simplified acute physiology score ii for post-cardiac surgery patients in intensive care unit
# Number of items: 0
# Title: characteristics and clinical subtypes of cancer patients in the intensive care unit: a retrospective observational study for two large databases
# Number of items: 0
# Title: optimal targets of the first 24-h partial pressure of carbon dioxide in patients with cerebral injury: data from the mimic-iii and iv database
# Number of items: 0
# Title: the prognostic value of calcium in post-cardiovascular surgery patients in the intensive care unit
# Number of items: 0
# Title: fluid choice matters in critically-ill patients with acute pancreatitis: lactated ringer's vs. isotonic saline
# Number of items: 0
# Title: prediction of acute kidney injury in icu with gradient boosting decision tree algorithms
# Number of items: 0
# Title: predicting duration of mechanical ventilation in acute respiratory distress syndrome using supervised machine learning
# Number of items: 0
# Title: prolonged dexmedetomidine infusion in critically ill adult patients: a retrospective analysis of a large clinical database multiparameter intelligent monitoring in intensive care iii
# Number of items: 0
# Title: platelet-to-lymphocyte ratio: a novel prognostic factor for prediction of 90-day outcomes in critically ill patients with diabetic ketoacidosis
# Number of items: 0
# Title: hospital-acquired dysmagnesemia and mortality in critically ill patients: data from mimic-iii database
# Number of items: 0
# Title: a review of mortality risk prediction models in smartphone applications
# Number of items: 0
# Title: benchmarking deep learning models on large healthcare datasets
# Number of items: 0
# Title: risk stratification of icu patients using topic models inferred from unstructured progress notes
# Number of items: 0
# Title: blood urea nitrogen and in-hospital mortality in critically ill patients with cardiogenic shock: analysis of the mimic-iii database
# Number of items: 0
# Title: early-phase urine output and severe-stage progression of oliguric acute kidney injury in critical care
# Number of items: 0
# Title: early warning of citric acid overdose and timely adjustment of regional citrate anticoagulation based on machine learning methods
# Number of items: 0
# Title: external validation of a laboratory prediction algorithm for the reduction of unnecessary labs in the critical care setting
# Number of items: 0
# Title: med7: a transferable clinical natural language processing model for electronic health records
# Number of items: 0
# Title: a nomogram for predicting hospital mortality in intensive care unit patients with acute myocardial infarction
# Number of items: 0
# Title: elevated urea-to-creatinine ratio provides a biochemical signature of muscle catabolism and persistent critical illness after major trauma
# Number of items: 0
# Title: prediction of extubation failure for neonates with respiratory distress syndrome using the mimic-ii clinical database
# Number of items: 0
# Title: body mass index is associated with the severity and all-cause mortality of acute kidney injury in critically ill patients: an analysis of a large critical care database
# Number of items: 0
# Title: predicting the need for intubation in the first 24 h after critical care admission using machine learning approaches
# Number of items: 0
# Title: development and validation of a sepsis mortality risk score for sepsis-3 patients in intensive care unit
# Number of items: 0
# Title: platelets as a prognostic marker for sepsis: a cohort study from the mimic-iii database
# Number of items: 0
# Title: novel prognostic predictor for primary pulmonary hypertension: focus on blood urea nitrogen
# Number of items: 0
# Title: risk factor analysis and nomogram for predicting in-hospital mortality in icu patients with sepsis and lung infection
# Number of items: 0
# Title: the value of admission serological indicators for predicting 28-day mortality in intensive care patients with acute heart failure: construction and validation of a nomogram
# Number of items: 0
# Title: the effect of dobutamine in sepsis: a propensity score matched analysis
# Number of items: 0
# Title: association between obesity and short-and long-term mortality in patients with acute respiratory distress syndrome based on the berlin definition
# Number of items: 0
# Title: the association between red blood cell distribution width and mortality in critically ill patients with acute kidney injury
# Number of items: 0
# Title: deep reinforcement learning for optimal critical care pain management with morphine using dueling double-deep q networks
# Number of items: 0
# Title: prognostic values of sofa score, qsofa score, and lods score for patients with sepsis
# Number of items: 0
# Title: association of initial serum total calcium concentration with mortality in critical illness
# Number of items: 0
# Title: association between the admission serum bicarbonate and short-term and long-term mortality in acute aortic dissection patients admitted to the intensive care unit
# Number of items: 0
# Title: acute hypotensive episodes prediction based on non-linear chaotic analysis
# Number of items: 0
# Title: venous thromboembolism in icu patients with intracerebral hemorrhage: risk factors and the prognosis after anticoagulation therapy
# Number of items: 0
# Title: early warnings of heart rate deterioration
# Number of items: 0
# Title: utilization of echocardiography after acute kidney injury was associated with improved outcomes in patients in intensive care unit
# Number of items: 0
# Title: blood urea nitrogen to serum albumin ratio independently predicts mortality in critically ill patients with acute pulmonary embolism
# Number of items: 0
# Title: prediction of mortality from respiratory distress among long-term mechanically ventilated patients
# Number of items: 0
# Title: predicting icu hemodynamic instability using continuous multiparameter trends
# Number of items: 0
# Title: identifying subpopulations of septic patients: a temporal data-driven approach
# Number of items: 0
# Title: predicting sepsis with a recurrent neural network using the mimic iii database
# Number of items: 0
# Title: is there opportunity for automated decision-support and closed-loop control in icu patients receiving vasopressor infusion?
# Number of items: 0
# Title: prediction of 60-day case fatality in critically ill patients receiving renal replacement therapy: external validation of a prediction model
# Number of items: 0
# Title: examining the concordance in the documented pressure injury site, stage, and count in medical information mart for intensive care-iii
# Number of items: 0
# Title: early prediction of acute kidney injury in critical care setting using clinical notes
# Number of items: 0
# Title: big data in healthcare - the promises, challenges and opportunities from a research perspective: a case study with a model database
# Number of items: 0
# Title: the association of red blood cell distribution width to platelet count ratio and 28-day mortality of patients with sepsis: a retrospective cohort study
# Number of items: 0
# Title: association of fluid balance with mortality in sepsis is modified by admission hemoglobin levels: a large database study
# Number of items: 0
# Title: anion gap was associated with inhospital mortality and adverse clinical outcomes of coronary care unit patients
# Number of items: 0
# Title: the neutrophil-lymphocyte ratio: a promising predictor of mortality in coronary care unit patients - a cohort study
# Number of items: 0
# Title: what can we learn about fall risk factors from ehr nursing notes? a text mining study
# Number of items: 0
# Title: platelet-to-lymphocyte ratio as a prognostic predictor of mortality for sepsis: interaction effect with disease severity-a retrospective study
# Number of items: 0
# Title: predicting mortality in critical care patients with fungemia using structured and unstructured data
# Number of items: 0
# Title: effect of spontaneous breathing on ventilator-free days in critically ill patients-an analysis of patients in a large observational cohort
# Number of items: 0
# Title: predicting acute hypotensive episodes: the 10th annual physionet/computers in cardiology challenge
# Number of items: 0
# Title: incidence, prognosis, and risk factors of sepsis-induced cardiomyopathy
# Number of items: 0
# Title: a physiological time series dynamics-based approach to patient monitoring and outcome prediction
# Number of items: 0
# Title: prevalence and temporal distribution of extrasystoles in septic icu patients: the feasibility of predicting fluid responsiveness using extrasystoles
# Number of items: 0
# Title: early coagulation disorder is associated with an increased risk of atrial fibrillation in septic patients
# Number of items: 0
# Title: noise detection in electrocardiogram signals for intensive care unit patients
# Number of items: 0
# Title: discharge recommendation based on a novel technique of homeostatic analysis
# Number of items: 0
# Title: external validation and improvement of life score as a prediction tool in critically ill cirrhosis patients
# Number of items: 0
# Title: the effect of long-term duration renal replacement therapy on outcomes of critically ill patients with acute kidney injury: a retrospective cohort study
# Number of items: 0
# Title: a novel risk-predicted nomogram for sepsis associated-acute kidney injury among critically ill patients
# Number of items: 0
# Title: machine learning applied to a cardiac surgery recovery unit and to a coronary care unit for mortality prediction
# Number of items: 0
# Title: development and validation of a model for the early prediction of the rrt requirement in patients with rhabdomyolysis
# Number of items: 0
# Title: estimating patient's health state using latent structure inferred from clinical time series and text
# Number of items: 0
# Title: mortality prediction in icus using a novel time-slicing cox regression method
# Number of items: 0
# Title: association between postoperative thrombocytopenia and outcomes after coronary artery bypass grafting surgery
# Number of items: 0
# Title: predicting intervention onset in the icu with switching state space models
# Number of items: 0
# Title: lactate/albumin ratio: an early prognostic marker in critically ill patients
# Number of items: 0
# Title: multimorbidity states associated with higher mortality rates in organ dysfunction and sepsis: a data-driven analysis in critical care
# Number of items: 0
# Title: computational signatures for post-cardiac arrest trajectory prediction: importance of early physiological time series
# Number of items: 0
# Title: postoperative neutrophil-to-lymphocyte ratio is associated with mortality in adult patients after cardiopulmonary bypass surgery: a cohort study
# Number of items: 0
# Title: predicting postoperative acute respiratory failure in critical care using nursing notes and physiological signals
# Number of items: 0
# Title: the association between serum anion gap and all-cause mortality in disseminated intravascular coagulation patients: a retrospective analysis
# Number of items: 0
# Title: thyroid hormone levels as a predictor marker predict the prognosis of patients with sepsis
# Number of items: 0
# Title: a visual analytic approach for the identification of icu patient subpopulations using icd diagnostic codes
# Number of items: 0
# Title: predicting mortality in diabetic icu patients using machine learning and severity indices
# Number of items: 0
# ...
# Number of items: 0
# Title: prediction of blood lactate values in critically ill patients: a retrospective multi-center cohort study
# Number of items: 0
# Title: evaluating semantic similarity methods for comparison of text-derived phenotype profiles
# Number of items: 0
# Title: predictive value of lymphocyte-to-monocyte ratio in critically ill patients with atrial fibrillation: a propensity score matching analysis
# Number of items: 0
# Title: a clinical prediction model to predict heparin treatment outcomes and provide dosage recommendations: development and validation study
# Number of items: 0
# Title: relationship between red blood cell distribution width and all-cause mortality in disseminated intravascular coagulation patients: a retrospective analysis
# Number of items: 0
# Title: predictive value of lactate in unselected critically ill patients: an analysis using fractional polynomials
# Number of items: 0
# Title: association between red blood cell distribution width-to-albumin ratio and prognosis of patients with aortic aneurysms
# Number of items: 0
# Title: mechanical power normalized to predicted body weight is associated with mortality in critically ill patients: a cohort study
# Number of items: 0
# Title: blood urea nitrogen to serum albumin ratio as a new prognostic indicator in critical patients with chronic heart failure
# Number of items: 0
# Title: association between anion gap and mortality in critically ill patients with cardiogenic shock
# Number of items: 0
# Title: an explainable cnn approach for medical codes prediction from clinical text
# Number of items: 0
# Title: lower mean corpuscular hemoglobin concentration is associated with poorer outcomes in intensive care unit admitted patients with acute myocardial infarction
# Number of items: 0
# Title: comparative efficacy of fentanyl and morphine in patients with or at risk for acute respiratory distress syndrome: a propensity score-matched cohort study
# Number of items: 0
# Title: a new scoring system for predicting in-hospital death in patients having liver cirrhosis with esophageal varices
# Number of items: 0
# Title: atrial fibrillation prediction from critically ill sepsis patients
# Number of items: 0
# Title: effectiveness of sodium bicarbonate infusion on mortality in septic patients with metabolic acidosis
# Number of items: 0
# Title: the association between the baseline and the change in neutrophil-to-lymphocyte ratio and short-term mortality in patients with acute respiratory distress syndrome
# Number of items: 0
# Title: development and evaluation of predictive alerts for hemodynamic instability in icu patients
# Number of items: 0
# Title: an early respiratory distress detection method with markov models
# Number of items: 0
# Title: classifying social determinants of health from unstructured electronic health records using deep learning-based natural language processing
# Number of items: 0
# Title: development and validation of an automated algorithm to detect atrial fibrillation within stored intensive care unit continuous electrocardiographic data: observational study
# Number of items: 0
# Title: preoperative liver function test abnormalities were associated with short-term and long-term prognosis in cardiac surgery patients without liver disease
# Number of items: 0
# Title: increased neutrophil percentage-to-albumin ratio is associated with all-cause mortality in patients with severe sepsis or septic shock
# Number of items: 0
# Title: robust algorithm to locate heart beats from multiple physiological waveforms by individual signal detector voting
# Number of items: 0
# Title: an adaptive weight learning-based multitask deep network for continuous blood pressure estimation using electrocardiogram signals
# Number of items: 0
# Title: relationship between early serum sodium and potassium levels and aki severity and prognosis in oliguric aki patients
# Number of items: 0
# Title: deceased serum bilirubin and albumin levels in the assessment of severity and mortality in patients with acute pancreatitis
# Number of items: 0
# Title: automatic medical code assignment via deep learning approach for intelligent healthcare
# Number of items: 0
# Title: novel density poincaré plot based machine learning method to detect atrial fibrillation from premature atrial/ventricular contractions
# Number of items: 0
# Title: extraction of information related to drug safety surveillance from electronic health record notes: joint modeling of entities and relations using knowledge-aware neural attentive models
# Number of items: 0
# Title: automated icd coding via unsupervised knowledge integration (unite)
# Number of items: 0
# Title: antipyretic therapy in critically ill patients with sepsis: an interaction with body temperature
# Number of items: 0
# Title: comparative effectiveness of midazolam, propofol, and dexmedetomidine in patients with or at risk for acute respiratory distress syndrome: a propensity score-matched cohort study
# Number of items: 0
# Title: construction of multi-parameter emergency database and preliminary application research
# Number of items: 0
# Title: prognostic role of ammonia in critical care patients without known hepatic disease
# Number of items: 0
# Title: medextractr: a targeted, customizable approach to medication extraction from electronic health records
# Number of items: 0
# Title: using machine learning to predict hyperchloremia in critically ill patients
# Number of items: 0
# Title: comparison of approaches for prediction of renal replacement therapy-free survival in patients with acute kidney injury
# Number of items: 0
# Title: increased body mass index linked to greater short- and long-term survival in sepsis patients: a retrospective analysis of a large clinical database
# Number of items: 0
# Title: a methodology for prediction of acute hypotensive episodes in icu via a risk scoring model including analysis of st-segment variations
# Number of items: 0
# Title: on-device reliability assessment and prediction of missing photoplethysmographic data using deep neural networks
# Number of items: 0
# Title: relationship between 24-h venous blood glucose variation and mortality among patients with acute respiratory failure
# Number of items: 0
# Title: a machine learning-based prediction of hospital mortality in patients with postoperative sepsis
# Number of items: 0
# Title: the neutrophil-lymphocyte ratio is associated with postoperative mortality of cardiac surgery
# Number of items: 0
# Title: clinical value of the lactate/albumin ratio and lactate/albumin ratio × age score in the assessment of prognosis in patients with sepsis
# Number of items: 0
# Title: empirical findings on the role of structured data, unstructured data, and their combination for automatic clinical phenotyping
# Number of items: 0
# Title: red blood cell distribution width as a predictor of 28-day mortality in critically ill patients with alcohol use disorder
# Number of items: 0
# Title: recurrent neural network models for blood pressure monitoring using ppg morphological features
# Number of items: 0
# Title: neutrophil-lymphocyte ratio is associated with all-cause mortality among critically ill patients with acute kidney injury
# Number of items: 0
# Title: risk potential for organ dysfunction associated with sodium bicarbonate therapy in critically ill patients with hemodynamic worsening
# Number of items: 0
# Title: associations between elevated systolic blood pressure and outcomes in critically ill patients: a retrospective cohort study and propensity analysis
# Number of items: 0
# Title: blood pressure estimation based on pulse arrival time and heart rate : a correlation analysis for critically ill patients<sup>.</sup>
# Number of items: 0
# Title: uncertainty-gated stochastic sequential model for ehr mortality prediction
# Number of items: 0
# Title: associations between early thiamine administration and clinical outcomes in critically ill patients with acute kidney injury
# Number of items: 0
# Title: the red blood cell distribution width-albumin ratio was a potential prognostic biomarker for diabetic ketoacidosis
# Number of items: 0
# Title: the red blood cell distribution width-albumin ratio: a promising predictor of mortality in stroke patients
# Number of items: 0
# Title: uncertainty-aware variational-recurrent imputation network for clinical time series
# Number of items: 0
# Title: relationship between first 24-h mean body temperature and clinical outcomes of post-cardiac surgery patients
# Number of items: 0
# Title: a new analytical framework for missing data imputation and classification with uncertainty: missing data imputation and heart failure readmission prediction
# Number of items: 0
# Title: discriminative and distinct phenotyping by constrained tensor factorization
# Number of items: 0
# Title: early biliary drainage is associated with favourable outcomes in critically-ill patients with acute cholangitis
# Number of items: 0
# Title: a data mining approach to reduce the false alarm rate of patient monitors
# Number of items: 0
# Title: fluctuations of driving pressure during mechanical ventilation indicates elevated central venous pressure and poor outcomes
# Number of items: 0
# Title: customization scenarios for de-identification of clinical notes
# Number of items: 0
# Title: effect of antipyretic therapy on mortality in critically ill patients with sepsis receiving mechanical ventilation treatment
# Number of items: 0
# Title: leukocytes in critical patients with asthma exacerbation
# Number of items: 0
# Title: development of a novel score for the prediction of hospital mortality in patients with severe sepsis: the use of electronic healthcare records with lasso regression
# Number of items: 0
# Title: hypoxic hepatitis - its biochemical profile, causes and risk factors of mortality in critically-ill patients: a cohort study of 565 patients
# Number of items: 0
# Title: time-related association between fluid balance and mortality in sepsis patients: interaction between fluid balance and haemodynamics
# Number of items: 0
# Title: association of post-operative systolic blood pressure variability with mortality after coronary artery bypass grafting
# Number of items: 0
# Title: impact of diagnosis code grouping method on clinical prediction model performance: a multi-site retrospective observational study
# Number of items: 0
# Title: acidosis predicts mortality independently from hyperlactatemia in patients with sepsis
# Number of items: 0
# Title: a hypotensive episode predictor for intensive care based on heart rate and blood pressure time series
# Number of items: 0
# Title: high serum iron level is associated with increased mortality in patients with sepsis
# Number of items: 0
# Title: reducing false alarm rates for critical arrhythmias using the arterial blood pressure waveform
# Number of items: 0
# Title: collective experience: a database-fuelled, inter-disciplinary team-led learning system
# Number of items: 0
# Title: recurrent neural networks for multivariate time series with missing values
# Number of items: 0
# Title: an explainable machine learning framework for lung cancer hospital length of stay prediction
# Number of items: 0
# Title: heart rate fluctuation and mortality in critically ill myocardial infarction patients: a retrospective cohort study
# Number of items: 0
# Title: construction and evaluation of a sepsis risk prediction model for urinary tract infection
# Number of items: 0
# Title: hypotension as a risk factor for acute kidney injury in icu patients
# Number of items: 0
# Title: predictive value of red blood cell distribution width in critically ill patients with atrial fibrillation: a retrospective cohort study
# Number of items: 0
# Title: prognostic association between perioperative red blood cell transfusion and postoperative cardiac surgery outcomes
# Number of items: 0
# Title: association of systemic immune-inflammation index with short-term mortality of congestive heart failure: a retrospective cohort study
# Number of items: 0
# Title: systemic immune-inflammation index for predicting the prognosis of critically ill patients with acute pancreatitis
# Number of items: 0
# Title: association of fib-4 index and clinical outcomes in critically ill patients with acute kidney injury: a cohort study
# Number of items: 0
# Title: a boosting inspired personalized threshold method for sepsis screening
# Number of items: 0
# Title: systemic immune-inflammation index as a promising predictor of mortality in patients with acute coronary syndrome: a real-world study
# Number of items: 0
# Title: serum anion gap is associated with risk of all-cause mortality in critically ill patients with acute myocardial infarction
# Number of items: 0
# Title: hierarchical information criterion for variable abstraction
# Number of items: 0
# Title: robust ppg motion artifact detection using a 1-d convolution neural network
# Number of items: 0
# Title: dr. agent: clinical predictive model via mimicked second opinions
# Number of items: 0
# Title: variable selection for causal mediation analysis using lasso-based methods
# Number of items: 0
# Title: role of empiric antifungal therapy in patients with perforated peptic ulcers
# Number of items: 0
# Title: reducing false arrhythmia alarm rates using robust heart rate estimation and cost-sensitive support vector machines
# Number of items: 0
# Title: development and validation of a nomogram to predict the mortality risk in elderly patients with arf
# Number of items: 0
# Title: association between albumin infusion and outcomes in patients with acute kidney injury and septic shock
# Number of items: 0
# Title: predictive value of red blood cell distribution width in septic shock patients with thrombocytopenia: a retrospective study using machine learning
# Number of items: 0
# Title: machine learning prediction models for prognosis of critically ill patients after open-heart surgery
# Number of items: 0
# Title: development and validation of a simple-to-use nomogram for predicting in-hospital mortality in patients with acute heart failure undergoing continuous renal replacement therapy
# Number of items: 0
# Title: serum total bilirubin level is associated with hospital mortality rate in adult critically ill patients: a retrospective study
# Number of items: 0
# Title: positive association between systemic immune-inflammatory index and mortality of cardiogenic shock
# Number of items: 0
# Title: x-cal: explicit calibration for survival analysis
# Number of items: 0
# Title: the hyperbilirubinemia and potential predictors influence on long-term outcomes in sepsis: a population-based propensity score-matched study
# Number of items: 0
# Title: red blood cell distribution width is associated with all-cause mortality in critically ill patients with cardiogenic shock
# Number of items: 0
# Title: taper: time-aware patient ehr representation
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <module>
#       6 search_url = base_url + urllib.parse.quote_plus(title)
#       7 content = simple_get(search_url)
# ----> 8 html = BeautifulSoup(content, 'html.parser')
#       9 # The publication type. May be present.
#      10 pub_item = html.find('a', alsec='ptyp')
#
# File ~/Documents/citation-tracker/env/lib/python3.8/site-packages/bs4/__init__.py:312, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     310 if hasattr(markup, 'read'):        # It's a file-type object.
#     311     markup = markup.read()
# --> 312 elif len(markup) <= 256 and (
#     313         (isinstance(markup, bytes) and not b'<' in markup)
#     314         or (isinstance(markup, str) and not '<' in markup)
#     315 ):
#     316     # Print out warnings for a couple beginner problems
#     317     # involving passing non-markup to Beautiful Soup.
#     318     # Beautiful Soup will still parse the input as markup,
#     319     # just in case that's what the user really wants.
#     320     if (isinstance(markup, str)
#     321         and not os.path.supports_unicode_filenames):
#     322         possible_filename = markup.encode("utf8")
#
# TypeError: object of type 'NoneType' has no len()

# %%
# Save the results
cx.write_lines(os.path.join('search_results', 'pubmed', 'publication-types.txt'), all_publication_types)
cx.write_lines(os.path.join('search_results', 'pubmed', 'mesh-terms.txt'), all_mesh_terms)

# %%
all_publication_types
# Out:
# ['Research Support, N.I.H., Extramural',
#  'Research Support, N.I.H., Intramural',
#  'Research Support, N.I.H., Extramural',
#  'Research Support, N.I.H., Extramural',
#  'Comparative Study',
#  "Research Support, Non-U.S. Gov't",
#  "Research Support, Non-U.S. Gov't",
#  'Research Support, N.I.H., Intramural',
#  "Research Support, Non-U.S. Gov't",
#  "Research Support, Non-U.S. Gov't",
#  'Research Support, N.I.H., Extramural',
#  'Research Support, N.I.H., Extramural',
#  'Research Support, N.I.H., Extramural',
#  "Research Support, Non-U.S. Gov't",
#  'Research Support, N.I.H., Extramural',
#  'Research Support, N.I.H., Extramural',
#  "Research Support, Non-U.S. Gov't",
#  'Research Support, N.I.H., Extramural',
#  'Observational Study',
#  "Research Support, Non-U.S. Gov't",
#  "Research Support, Non-U.S. Gov't",
#  "Research Support, Non-U.S. Gov't",
#  'Research Support, N.I.H., Extramural',
#  'Comparative Study',
#  'Research Support, N.I.H., Extramural',
#  "Research Support, Non-U.S. Gov't",
#  'Research Support, N.I.H., Extramural',
#  "Research Support, U.S. Gov't, Non-P.H.S.",
#  'Research Support, N.I.H., Extramural',
#  'Research Support, N.I.H., Extramural',
#  "Research Support, Non-U.S. Gov't",
#  'Evaluation Studies',
#  "Research Support, U.S. Gov't, Non-P.H.S.",
#  "Research Support, Non-U.S. Gov't",
#  'Research Support, N.I.H., Extramural',
#  "Research Support, Non-U.S. Gov't",
#  'Research Support, N.I.H., Extramural',
#  'Comparative Study',
#  "Research Support, Non-U.S. Gov't",
#  'Comparative Study',
#  'Comparative Study',
#  "Research Support, Non-U.S. Gov't",
#  'Research Support, N.I.H., Extramural',
#  'Research Support, N.I.H., Intramural',
#  'Comparative Study',
#  'Research Support, N.I.H., Extramural',
#  'Research Support, N.I.H., Extramural']

# %%
all_mesh_terms
# Out:
# ['Aged',
#  'Aged, 80 and over',
#  'Algorithms',
#  'Boston',
#  'Female',
#  'Hospital Mortality*',
#  'Humans',
#  'Intensive Care Units/statistics & numerical data*',
#  'Machine Learning/statistics & numerical data*',
#  'Male',
#  'Middle Aged',
#  'ROC Curve',
#  'Reproducibility of Results',
#  'Risk',
#  'Severity of Illness Index*',
#  'Acute Disease',
#  'Aged',
#  'Databases, Factual*',
#  'Erythrocyte Indices*',
#  'Female',
#  'Humans',
#  'Intensive Care Units*',
#  'Male',
#  'Middle Aged',
#  'Multivariate Analysis',
#  'Pancreatitis/blood*',
#  'Pancreatitis/diagnosis*',
#  'Prognosis',
#  'Retrospective Studies',
#  'Academic Medical Centers',
#  'Adult',
#  'African Americans/statistics & numerical data',
#  'Aged',
#  'Aged, 80 and over',
#  'Asian Americans/statistics & numerical data',
#  'Boston/epidemiology',
#  'Continental Population Groups/statistics & numerical data*',
#  'Electronic Health Records',
#  'European Continental Ancestry Group/statistics & numerical data',
#  'Female',
#  'Health Status Disparities*',
#  'Hospital Mortality/ethnology*',
#  'Humans',
#  'Intensive Care Units*',
#  'Male',
#  'Middle Aged',
#  'Retrospective Studies',
#  'Adult',
#  'Artificial Intelligence',
#  'Critical Care/statistics & numerical data*',
#  'Databases, Factual*',
#  'Decision Support Systems, Clinical*',
#  'Expert Systems',
#  'Female',
#  'Humans',
#  'Intensive Care Units/statistics & numerical data*',
#  'Medical Informatics Applications',
#  'Medical Records Systems, Computerized',
#  'Monitoring, Physiologic/instrumentation*',
#  'Quality Control',
#  'Retrospective Studies',
#  'United States',
#  'Algorithms*',
#  'Databases, Factual*',
#  'Humans',
#  'Intensive Care Units*',
#  'Intubation',
#  'Pressure',
#  'Respiration, Artificial*',
#  'Time Factors',
#  'Access to Information',
#  'Biomedical Research',
#  'Critical Care*',
#  'Databases, Factual',
#  'Humans',
#  'Internet',
#  'Software*',
#  'User-Computer Interface*',
#  'Aged',
#  'Critical Care',
#  'Databases, Factual*',
#  'Female',
#  'Hospital Mortality*',
#  'Humans',
#  'Intensive Care Units*',
#  'Male',
#  'Middle Aged',
#  'Norepinephrine/antagonists & inhibitors*',
#  'Patient Admission*',
#  'Retrospective Studies',
#  'Serotonin Uptake Inhibitors/therapeutic use*',
#  'Blood Pressure',
#  'Circadian Rhythm',
#  'Critical Care*',
#  'Data Mining*',
#  'Databases, Factual*',
#  'Heart Rate',
#  'Humans',
#  'Medical Informatics*',
#  'Aged',
#  'Cell Count',
#  'Erythrocyte Volume*',
#  'Female',
#  'Humans',
#  'Intensive Care Units*',
#  'Lymphocytes/cytology*',
#  'Male',
#  'Middle Aged',
#  'Neutrophils/cytology*',
#  'Patient Admission*',
#  'Prognosis',
#  'Retrospective Studies',
#  'Subarachnoid Hemorrhage/blood',
#  'Subarachnoid Hemorrhage/diagnosis*',
#  'Subarachnoid Hemorrhage/physiopathology*',
#  'Subarachnoid Hemorrhage/therapy',
#  'Adult',
#  'Classification/methods*',
#  'Electronic Health Records*/classification',
#  'Humans',
#  'Infant, Newborn',
#  'Information Storage and Retrieval*',
#  'Intensive Care Units',
#  'Jaundice, Neonatal/classification',
#  'Jaundice, Neonatal/diagnosis',
#  'Phototherapy/statistics & numerical data',
#  'Respiration, Artificial/statistics & numerical data',
#  'Support Vector Machine*',
#  'Aged',
#  'Calcium/chemistry*',
#  'Calcium/metabolism*',
#  'Critical Illness/mortality*',
#  'Databases, Factual*',
#  'Female',
#  'Humans',
#  'Intensive Care Units/statistics & numerical data',
#  'Logistic Models',
#  'Male',
#  'Medical Informatics/methods*',
#  'Middle Aged',
#  'Predictive Value of Tests',
#  'Blood Pressure',
#  'Critical Care',
#  'Forecasting',
#  'Heart Rate',
#  'Humans',
#  'Intensive Care Units*',
#  'Machine Learning*',
#  'Multiple Organ Failure',
#  'Risk Assessment/methods*',
#  'Shock, Septic*',
#  'Critical Care',
#  'Databases, Factual',
#  'Humans',
#  'Hyperlactatemia*',
#  'Intensive Care Units',
#  'Sepsis',
#  'Shock, Septic',
#  'Adult',
#  'Aged',
#  'Aged, 80 and over',
#  'Databases, Factual',
#  'Demography',
#  'Female',
#  'Humans',
#  'Intensive Care Units*',
#  'Linear Models',
#  'Male',
#  'Middle Aged',
#  'Models, Biological',
#  'Probability',
#  'Sepsis/diagnosis*',
#  'Sepsis/therapy*',
#  'Signal Processing, Computer-Assisted',
#  'Adult',
#  'Aged',
#  'Aged, 80 and over',
#  'Body Mass Index',
#  'Boston/epidemiology',
#  'Cohort Studies',
#  'Critical Illness/mortality*',
#  'Female',
#  'Humans',
#  'Intensive Care Units/statistics & numerical data*',
#  'Male',
#  'Middle Aged',
#  'Obesity/complications',
#  'Obesity/mortality*',
#  'Overweight/complications',
#  'Overweight/mortality*',
#  'Proportional Hazards Models',
#  'Risk Factors',
#  'Severity of Illness Index',
#  'Survival Analysis',
#  'Databases, Factual*',
#  'Electronic Health Records*',
#  'Humans',
#  'Medical Informatics Applications*',
#  'Clinical Laboratory Techniques/standards*',
#  'Databases, Factual/statistics & numerical data*',
#  'Humans',
#  'Information Theory*',
#  'Intensive Care Units/standards*',
#  'Unnecessary Procedures/standards*',
#  'Access to Information*',
#  'Adult',
#  'Critical Care*',
#  'Databases, Factual*',
#  'Humans',
#  'Monitoring, Physiologic*',
#  'Research*',
#  'Wavelet Analysis',
#  'Algorithms',
#  'Blood Pressure/physiology*',
#  'Data Mining/methods*',
#  'Humans',
#  'Hypotension/diagnosis*',
#  'Hypotension/prevention & control*',
#  'Intensive Care Units*',
#  'Pattern Recognition, Automated/methods*',
#  'Risk Factors',
#  'Algorithms',
#  'Biomarkers',
#  'Databases, Factual',
#  'Fuzzy Logic*',
#  'Heart Failure/diagnosis*',
#  'Heart Failure/etiology',
#  'Heart Failure/physiopathology*',
#  'Hemodynamics',
#  'Humans',
#  'Intensive Care Units*',
#  'Models, Theoretical*',
#  'Patient Admission',
#  'Prognosis',
#  'Retrospective Studies',
#  'Severity of Illness Index',
#  'Stroke Volume*',
#  'Ventricular Function, Left*',
#  'Algorithms',
#  'Artifacts',
#  'Critical Care',
#  'Humans',
#  'Hypovolemia*',
#  'Photoplethysmography',
#  'Signal Processing, Computer-Assisted',
#  'Boston',
#  'Critical Care*',
#  'Electronic Health Records/statistics & numerical data*',
#  'Humans',
#  'Intensive Care Units*/organization & administration',
#  'Middle Aged',
#  'Prognosis',
#  'Quality Assurance, Health Care',
#  'Reproducibility of Results',
#  'Retrospective Studies',
#  'Severity of Illness Index*',
#  'Data Mining/methods*',
#  'Electronic Health Records/classification*',
#  'Humans',
#  'Intensive Care Units*',
#  'Medical Informatics Applications*',
#  'Nurses',
#  'Regression Analysis',
#  'Risk Assessment',
#  'Acute Kidney Injury/mortality*',
#  'Critical Care',
#  'Hospital Mortality*',
#  'Humans',
#  'Intensive Care Units',
#  'Prognosis',
#  'ROC Curve',
#  'Sensitivity and Specificity',
#  'Support Vector Machine*',
#  'Fuzzy Logic',
#  'Humans',
#  'Intensive Care Units/organization & administration*',
#  'Monitoring, Physiologic/methods*',
#  'Risk Assessment*',
#  'Algorithms',
#  'Critical Care/statistics & numerical data*',
#  'Critical Illness/therapy*',
#  'Data Mining/methods',
#  'Data Mining/statistics & numerical data*',
#  'Databases, Factual/statistics & numerical data',
#  'Humans',
#  'Information Storage and Retrieval/methods',
#  'Information Storage and Retrieval/statistics & numerical data*',
#  'Intensive Care Units/statistics & numerical data',
#  'Models, Theoretical',
#  'Programming Languages',
#  'Reproducibility of Results',
#  'Computational Biology/methods',
#  'Critical Care/statistics & numerical data*',
#  'Databases, Factual/statistics & numerical data',
#  'Electronic Health Records/statistics & numerical data',
#  'Female',
#  'Humans',
#  'Machine Learning/statistics & numerical data*',
#  'Male',
#  'Supervised Machine Learning/statistics & numerical data',
#  'Unsupervised Machine Learning/statistics & numerical data',
#  'Algorithms',
#  'Clinical Alarms*',
#  'Critical Care/methods*',
#  'Diagnosis, Computer-Assisted/methods*',
#  'Diagnostic Errors/prevention & control*',
#  'Electrocardiography/methods*',
#  'False Positive Reactions',
#  'Humans',
#  'Intensive Care Units',
#  'Pattern Recognition, Automated/methods',
#  'Reproducibility of Results',
#  'Sensitivity and Specificity',
#  'Tachycardia, Ventricular/diagnosis*',
#  'Wavelet Analysis',
#  'Artificial Intelligence*',
#  'Boston',
#  'Decision Making, Computer-Assisted',
#  'Female',
#  'Fluid Therapy*',
#  'Humans',
#  'Information Storage and Retrieval',
#  'Intensive Care Units*',
#  'Male',
#  'Vasoconstrictor Agents/therapeutic use',
#  'Adult',
#  'Aged',
#  'Algorithms',
#  'Computational Biology',
#  'Disseminated Intravascular Coagulation*',
#  'Electronic Health Records*',
#  'Female',
#  'Humans',
#  'Information Storage and Retrieval',
#  'Male',
#  'Middle Aged',
#  'Patient-Specific Modeling*',
#  'Prospective Studies',
#  'Retrospective Studies',
#  'Software*',
#  'Artificial Intelligence*',
#  'Databases, Factual*',
#  'Decision Support Systems, Clinical*',
#  'Expert Systems*',
#  'Humans',
#  'Information Systems',
#  'Intensive Care Units*',
#  'Medical Records Systems, Computerized',
#  'Monitoring, Physiologic/instrumentation*',
#  'Signal Processing, Computer-Assisted',
#  'Software',
#  'Acute Disease',
#  'Algorithms',
#  'Databases, Factual',
#  'Diagnosis, Computer-Assisted/methods*',
#  'Humans',
#  'Hypotension/diagnosis*',
#  'Hypotension/physiopathology',
#  'Intensive Care Units',
#  'Neural Networks (Computer)*',
#  'Predictive Value of Tests',
#  'Regression Analysis',
#  'Reproducibility of Results',
#  'Signal Processing, Computer-Assisted*',
#  'Humans',
#  'Intensive Care Units*',
#  'Logistic Models',
#  'Natural Language Processing',
#  'Resuscitation*',
#  'Adult',
#  'Algorithms',
#  'Brain Injuries/epidemiology',
#  'Child',
#  'Critical Care',
#  'Databases, Factual',
#  'Hospital Mortality*',
#  'Humans',
#  'Intensive Care Units',
#  'Intensive Care Units, Pediatric',
#  'Medical Informatics/methods*',
#  'Models, Statistical',
#  'Outcome Assessment (Health Care)',
#  'Predictive Value of Tests',
#  'Prognosis',
#  'ROC Curve',
#  'Regression Analysis',
#  'Risk Assessment/methods*',
#  'Access to Information',
#  'Biomedical Research*',
#  'Comorbidity',
#  'Critical Care*',
#  'Data Mining',
#  'Databases, Factual*',
#  'Electronic Health Records',
#  'Humans',
#  'Organ Dysfunction Scores',
#  'ROC Curve',
#  'Reproducibility of Results',
#  'Sepsis',
#  'Severity of Illness Index',
#  'Therapeutics',
#  'Algorithms',
#  'Databases, Factual',
#  'Humans',
#  'Intensive Care Units*',
#  'Acute Disease',
#  'Aged',
#  'Critical Illness/mortality*',
#  'Databases, Factual',
#  'Female',
#  'Humans',
#  'Intensive Care Units',
#  'Isotonic Solutions/administration & dosage*',
#  'Logistic Models',
#  'Male',
#  'Massachusetts/epidemiology',
#  'Middle Aged',
#  'Pancreatitis/etiology',
#  'Pancreatitis/mortality*',
#  'Pancreatitis/therapy*',
#  'Resuscitation/methods*',
#  'Retrospective Studies',
#  "Ringer's Lactate",
#  'Sodium Chloride/administration & dosage*',
#  'Adult',
#  'Aged',
#  'Area Under Curve',
#  'Cross-Sectional Studies',
#  'Female',
#  'Humans',
#  'Intensive Care Units/statistics & numerical data*',
#  'Machine Learning*',
#  'Male',
#  'Middle Aged',
#  'Patient Readmission/statistics & numerical data*',
#  'ROC Curve',
#  'Retrospective Studies',
#  'Tertiary Care Centers',
#  'United Kingdom',
#  'Adult',
#  'Algorithms',
#  'Area Under Curve',
#  'Hospital Mortality',
#  'Humans',
#  'Intensive Care Units*',
#  'Models, Theoretical',
#  'Natural Language Processing*',
#  'Nursing Records*',
#  'Risk Assessment/methods*',
#  'Severity of Illness Index',
#  'Unified Medical Language System',
#  'Adult',
#  'Aged',
#  'Critical Illness',
#  'Diabetic Ketoacidosis/blood*',
#  'Diabetic Ketoacidosis/mortality*',
#  'Female',
#  'Humans',
#  'Intensive Care Units',
#  'Kaplan-Meier Estimate',
#  'Longitudinal Studies',
#  'Lymphocyte Count',
#  'Male',
#  'Middle Aged',
#  'Patient Readmission*',
#  'Platelet Count',
#  'Predictive Value of Tests',
#  'Prognosis',
#  'Retrospective Studies',
#  'Time Factors',
#  'Airway Extubation/statistics & numerical data*',
#  'Algorithms',
#  'Artificial Intelligence*',
#  'Database Management Systems',
#  'Databases, Factual*',
#  'Decision Support Systems, Management*',
#  'Diagnosis, Computer-Assisted/methods',
#  'Female',
#  'Humans',
#  'Incidence',
#  'Infant, Newborn',
#  'Male',
#  'New York/epidemiology',
#  'Prognosis',
#  'Reproducibility of Results',
#  'Respiration, Artificial/statistics & numerical data*',
#  'Respiratory Distress Syndrome, Newborn/diagnosis*',
#  'Respiratory Distress Syndrome, Newborn/epidemiology',
#  'Respiratory Distress Syndrome, Newborn/rehabilitation*',
#  'Risk Assessment',
#  'Sensitivity and Specificity',
#  'Treatment Failure',
#  'Critical Care',
#  'Humans',
#  'Intensive Care Units',
#  'Length of Stay',
#  'Logistic Models',
#  'Patient Readmission*',
#  'Retrospective Studies',
#  'Algorithms',
#  'Blood Pressure',
#  'Heart Rate/physiology',
#  'Hemodynamics/physiology*',
#  'Humans',
#  'Intensive Care Units/statistics & numerical data*',
#  'Monitoring, Physiologic',
#  'Multiple Organ Failure/diagnosis*',
#  'Multiple Organ Failure/physiopathology*',
#  'Neural Networks (Computer)',
#  'ROC Curve',
#  'Regression Analysis',
#  'Reproducibility of Results',
#  'Sensitivity and Specificity',
#  'Software',
#  'Time Factors',
#  'Humans',
#  'Hypotension/diagnosis*',
#  'Intensive Care Units',
#  'Nonlinear Dynamics',
#  'Software',
#  'Heart Rate/physiology*',
#  'Humans',
#  'Intensive Care Units',
#  'Internet',
#  'Sepsis/diagnosis',
#  'Sepsis/pathology*',
#  'User-Computer Interface',
#  'Vital Signs/physiology',
#  'Algorithms',
#  'Decision Trees',
#  'Female',
#  'Hospital Mortality*',
#  'Humans',
#  'Intensive Care Units',
#  'Logistic Models',
#  'Male',
#  'Multivariate Analysis',
#  'Respiration Disorders/mortality*',
#  'Respiration, Artificial*',
#  'Time Factors',
#  'Adult',
#  'Blood Pressure/physiology',
#  'Critical Care/methods*',
#  'Humans',
#  'Monitoring, Physiologic/methods*',
#  'Vasoconstrictor Agents*/administration & dosage',
#  'Vasoconstrictor Agents*/therapeutic use',
#  'Aged',
#  'Algorithms',
#  'Critical Care/methods*',
#  'Critical Illness',
#  'Electronic Data Processing',
#  'Female',
#  'Health Status',
#  'Humans',
#  'Intensive Care Units*',
#  'Least-Squares Analysis',
#  'Linear Models',
#  'Machine Learning',
#  'Male',
#  'Medical Informatics',
#  'Middle Aged',
#  'Monitoring, Ambulatory/methods*',
#  'Principal Component Analysis',
#  'Reproducibility of Results',
#  'Sensitivity and Specificity',
#  'Signal Processing, Computer-Assisted',
#  'Vital Signs',
#  'Adult',
#  'Algorithms',
#  'Blood Pressure/physiology',
#  'Databases, Factual',
#  'Female',
#  'Health Status Indicators*',
#  'Heart Rate/physiology',
#  'Hospital Mortality',
#  'Humans',
#  'Intensive Care Units',
#  'Male',
#  'Medical Informatics',
#  'Models, Statistical*',
#  'Monitoring, Physiologic/methods*',
#  'Prognosis',
#  'Reproducibility of Results',
#  'Tilt-Table Test',
#  'Adult',
#  'Datasets as Topic',
#  'Decision Making, Computer-Assisted*',
#  'Decision Support Systems, Clinical',
#  'Humans',
#  'Intensive Care Units',
#  'Length of Stay',
#  'Patient Discharge*',
#  'Prognosis',
#  'ROC Curve',
#  'Retrospective Studies',
#  'Risk Assessment/methods',
#  'Risk Factors',
#  'Triage/methods',
#  'Data Mining*',
#  'Databases, Factual',
#  'Humans',
#  'Intensive Care Units*',
#  'Regression Analysis*',
#  'Support Vector Machine*',
#  'Critical Care/methods*',
#  'Databases, Factual',
#  'Humans',
#  'Medical Records',
#  'Nurses',
#  'Postoperative Complications/diagnosis*',
#  'Postoperative Complications/epidemiology*',
#  'Respiratory Distress Syndrome, Adult/diagnosis*',
#  'Respiratory Distress Syndrome, Adult/epidemiology*',
#  'Respiratory Rate/physiology*',
#  'Risk',
#  'Adult',
#  'Critical Illness',
#  'Cross Infection/diagnosis*',
#  'Electronic Health Records*',
#  'Humans',
#  'Iatrogenic Disease',
#  'Intensive Care Units/organization & administration',
#  'International Classification of Diseases',
#  'Phenotype*',
#  'Time',
#  'Critical Care*',
#  'Data Interpretation, Statistical',
#  'Hemodynamics*',
#  'Humans',
#  'Hypotension/diagnosis*',
#  'Hypotension/physiopathology*',
#  'Pattern Recognition, Automated/methods*',
#  'Regression Analysis',
#  'Acute Disease',
#  'Algorithms',
#  'Blood Pressure/physiology',
#  'Databases, Factual',
#  'Early Diagnosis*',
#  'Humans',
#  'Intensive Care Units',
#  'Models, Theoretical',
#  'Sensitivity and Specificity',
#  'Anti-Bacterial Agents/therapeutic use',
#  'Clostridium Infections/drug therapy',
#  'Clostridium Infections/immunology*',
#  'Clostridium difficile*',
#  'Critical Illness',
#  'Delayed Diagnosis',
#  'Electronic Health Records',
#  'Genomics',
#  'Humans',
#  'Intensive Care Units',
#  'International Classification of Diseases',
#  'Leukocyte Count*',
#  'Leukocytosis/etiology',
#  'Medical Records Systems, Computerized',
#  'Phenotype*',
#  'Reference Values',
#  'Acute Disease',
#  'Algorithms',
#  'Biomedical Engineering/methods',
#  'Blood Pressure',
#  'Cardiology/methods',
#  'Humans',
#  'Hypotension/diagnosis*',
#  'Hypotension/physiopathology*',
#  'Neural Networks (Computer)',
#  'Signal Processing, Computer-Assisted*',
#  'Software',
#  'Time Factors',
#  'Adolescent',
#  'Adult',
#  'Aged',
#  'Algorithms',
#  'Child',
#  'Child, Preschool',
#  'Electrocardiography*',
#  'Fourier Analysis',
#  'Humans',
#  'Infant',
#  'Intensive Care Units',
#  'Middle Aged',
#  'Plethysmography*',
#  'Respiratory Rate/physiology*',
#  'Signal Processing, Computer-Assisted',
#  'Young Adult',
#  'Algorithms*',
#  'Critical Care/methods*',
#  'Decision Support Systems, Clinical*',
#  'Diagnosis, Computer-Assisted/methods*',
#  'Hypotension/diagnosis*',
#  'Monitoring, Physiologic/methods*',
#  'Multiple Organ Failure/diagnosis*',
#  'New York',
#  'Prognosis',
#  'Reproducibility of Results',
#  'Sensitivity and Specificity',
#  'Algorithms',
#  'Hospital Mortality',
#  'Humans',
#  'Intensive Care Units',
#  'Markov Chains*',
#  'Monitoring, Physiologic/methods*',
#  'Oxygen/metabolism',
#  'Partial Pressure',
#  'Pattern Recognition, Automated',
#  'Respiration Disorders/diagnosis*',
#  'Respiration Disorders/mortality',
#  'Respiration Disorders/physiopathology*',
#  'Respiratory Rate/physiology',
#  'Algorithms*',
#  'Databases, Factual',
#  'False Positive Reactions',
#  'Heart/physiology*',
#  'Heart Function Tests/methods*',
#  'Heart Rate*',
#  'Humans',
#  'Sensitivity and Specificity',
#  'Software',
#  'Adult',
#  'Aged',
#  'Aged, 80 and over',
#  'Antipyretics/adverse effects*',
#  'Antipyretics/therapeutic use*',
#  'Body Temperature/drug effects*',
#  'Body Temperature/physiology',
#  'Critical Care',
#  'Critical Illness',
#  'Cryotherapy/adverse effects',
#  'Databases, Factual',
#  'Female',
#  'Humans',
#  'Male',
#  'Middle Aged',
#  'Multivariate Analysis',
#  'Probability',
#  'Risk Factors',
#  'Sepsis/drug therapy*',
#  'Sepsis/mortality',
#  'Sepsis/physiopathology*',
#  'Computer Simulation*',
#  'Decision Support Techniques*',
#  'Electronic Health Records*',
#  'Humans',
#  'Models, Statistical',
#  'Phenotype*',
#  'Algorithms*',
#  'Blood Pressure Determination/methods*',
#  'Computer Simulation',
#  'Critical Care/methods',
#  'Diagnosis, Computer-Assisted/methods*',
#  'Electrocardiography/methods*',
#  'Humans',
#  'Hypotension/diagnosis*',
#  'Models, Cardiovascular*',
#  'Reproducibility of Results',
#  'Risk Assessment/methods',
#  'Risk Factors',
#  'Sensitivity and Specificity',
#  'Acute Kidney Injury/blood*',
#  'Acute Kidney Injury/mortality',
#  'Acute Kidney Injury/physiopathology',
#  'Adult',
#  'Age Factors',
#  'Aged',
#  'Alanine Transaminase/blood',
#  'Bilirubin/blood',
#  'Biomarkers/blood',
#  'Critical Illness/mortality*',
#  'Female',
#  'Hepatitis/blood*',
#  'Hepatitis/mortality',
#  'Hepatitis/physiopathology',
#  'Hospital Mortality',
#  'Humans',
#  'Hypoxia/blood*',
#  'Hypoxia/mortality',
#  'Hypoxia/physiopathology',
#  'L-Lactate Dehydrogenase/blood',
#  'Male',
#  'Middle Aged',
#  'Predictive Value of Tests',
#  'Retrospective Studies',
#  'Risk Factors',
#  'Vasoconstrictor Agents/therapeutic use',
#  'Adult',
#  'Aged',
#  'Aged, 80 and over',
#  'Critical Care',
#  'Critical Illness/mortality',
#  'Electronic Health Records/statistics & numerical data*',
#  'Hospital Mortality*',
#  'Humans',
#  'Medical Informatics/methods*',
#  'Middle Aged',
#  'ROC Curve',
#  'Regression Analysis*',
#  'Sepsis/diagnosis',
#  'Sepsis/epidemiology',
#  'Sepsis/mortality*',
#  'Young Adult',
#  'Equipment Failure*',
#  'Humans',
#  'Information Storage and Retrieval*',
#  'Monitoring, Physiologic/instrumentation*',
#  'Algorithms*',
#  'Arrhythmias, Cardiac/diagnosis*',
#  'Artificial Intelligence',
#  'Blood Pressure Determination/methods*',
#  'Critical Care/methods*',
#  'Diagnosis, Computer-Assisted/methods*',
#  'Electrocardiography/methods*',
#  'False Positive Reactions',
#  'Humans',
#  'Pattern Recognition, Automated/methods*',
#  'Reproducibility of Results',
#  'Sensitivity and Specificity',
#  'Aged',
#  'Aged, 80 and over',
#  'Antipyretics/adverse effects*',
#  'Boston/epidemiology',
#  'Critical Illness/mortality*',
#  'Female',
#  'Fever/drug therapy*',
#  'Fever/etiology',
#  'Humans',
#  'Male',
#  'Middle Aged',
#  'Sepsis/complications*',
#  'Sepsis/mortality',
#  'Aged',
#  'Area Under Curve',
#  'Arterial Pressure',
#  'Bilirubin/blood',
#  'Biomarkers/blood',
#  'Creatinine/blood',
#  'Critical Illness',
#  'Databases, Factual',
#  'Decision Support Techniques*',
#  'Female',
#  'Humans',
#  'International Normalized Ratio',
#  'Kaplan-Meier Estimate',
#  'Liver Cirrhosis/blood',
#  'Liver Cirrhosis/complications',
#  'Liver Cirrhosis/diagnosis*',
#  'Liver Cirrhosis/mortality*',
#  'Liver Failure/blood',
#  'Liver Failure/diagnosis*',
#  'Liver Failure/etiology',
#  'Liver Failure/mortality*',
#  'Male',
#  'Middle Aged',
#  'Models, Biological*',
#  'Multiple Organ Failure/blood',
#  'Multiple Organ Failure/diagnosis*',
#  'Multiple Organ Failure/etiology',
#  'Multiple Organ Failure/mortality*',
#  'Organ Dysfunction Scores*',
#  'Predictive Value of Tests',
#  'Prognosis',
#  'ROC Curve',
#  'Reproducibility of Results',
#  'Risk Assessment',
#  'Risk Factors',
#  'Time Factors',
#  'Blood Glucose/analysis*',
#  'Critical Illness/classification*',
#  'Critical Illness/mortality',
#  'Female',
#  'Humans',
#  'Hyperglycemia/diagnosis',
#  'Hypoglycemia/diagnosis',
#  'Male',
#  'Middle Aged',
#  'Organ Dysfunction Scores',
#  'Prognosis',
#  'Proportional Hazards Models',
#  'Reproducibility of Results',
#  'Severity of Illness Index*',
#  'Arrhythmias, Cardiac/diagnosis',
#  'Arrhythmias, Cardiac/physiopathology*',
#  'Clinical Alarms*',
#  'Costs and Cost Analysis*',
#  'Electrocardiography/instrumentation*',
#  'False Positive Reactions',
#  'Heart Rate*',
#  'Humans',
#  'Signal Processing, Computer-Assisted',
#  'Support Vector Machine/economics*',
#  'Time Factors',
#  'Adult',
#  'Alcoholism/mortality*',
#  'Female',
#  'Humans',
#  'Male',
#  'Middle Aged',
#  'Models, Biological*',
#  'Predictive Value of Tests',
#  'Software*',
#  'Time Factors',
#  'Triage/methods*',
#  'Algorithms',
#  'Electronic Health Records',
#  'Humans',
#  'Models, Theoretical*',
#  'Mortality*',
#  'Time Factors',
#  'Algorithms',
#  'Cluster Analysis',
#  'Databases, Factual*',
#  'Aged',
#  'Critical Illness/mortality',
#  'Female',
#  'Health Status Indicators',
#  'Humans',
#  'Liver Cirrhosis/diagnosis',
#  'Liver Cirrhosis/mortality*',
#  'Male',
#  'Middle Aged',
#  'Prognosis',
#  'Respiratory Insufficiency/diagnosis',
#  'Respiratory Insufficiency/mortality*',
#  'Retrospective Studies',
#  'Risk Assessment',
#  'Severity of Illness Index*',
#  'Algorithms',
#  'Databases, Factual',
#  'Humans',
#  'Photoplethysmography/methods*',
#  'Signal Processing, Computer-Assisted*',
#  'Ventricular Premature Complexes/diagnosis*',
#  'Adult',
#  'Computational Biology',
#  'Databases, Factual',
#  'Hemodynamics',
#  'Humans',
#  'Models, Biological',
#  'Multivariate Analysis',
#  'Prognosis',
#  'Shock, Septic/mortality*',
#  'Shock, Septic/physiopathology',
#  'Aged',
#  'Aged, 80 and over',
#  'Critical Care',
#  'Databases, Factual',
#  'Humans',
#  'Middle Aged',
#  'Mortality',
#  'Patient Discharge*',
#  'Pattern Recognition, Automated',
#  'Prognosis',
#  'Algorithms',
#  'Blood Pressure',
#  'Electrocardiography',
#  'Heart Ventricles/pathology',
#  'Heart Ventricles/physiopathology',
#  'Hemodynamics*',
#  'Humans',
#  'Monitoring, Physiologic/instrumentation*',
#  'Tachycardia, Ventricular/physiopathology*',
#  'Wavelet Analysis',
#  'Algorithms',
#  'Databases, Factual',
#  'Electronic Health Records*',
#  'Female',
#  'Humans',
#  'Infant, Newborn*',
#  'Massachusetts',
#  'Mothers*',
#  'Pattern Recognition, Automated*',
#  'Algorithms',
#  'Datasets as Topic',
#  'Electronic Health Records/organization & administration*',
#  'Electronic Health Records/standards',
#  'Health Information Exchange/standards*',
#  'Health Information Interoperability/standards',
#  'Health Level Seven',
#  'Humans',
#  'Internet',
#  'Pilot Projects',
#  'Software*',
#  'Algorithms',
#  'Databases, Factual',
#  'Dose-Response Relationship, Drug',
#  'Heparin/administration & dosage*',
#  'Heparin/pharmacology*',
#  'Humans',
#  'Learning*',
#  'Length of Stay',
#  'Markov Chains',
#  'Reinforcement (Psychology)*',
#  'Retrospective Studies',
#  'Bayes Theorem',
#  'Data Mining*',
#  'Humans',
#  'Knowledge Bases',
#  'Linguistics',
#  'Medical Informatics/methods',
#  ...]

# %%
set(all_mesh_terms)
# Out:
# {'Academic Medical Centers',
#  'Access to Information',
#  'Access to Information*',
#  'Acute Disease',
#  'Acute Kidney Injury/blood*',
#  'Acute Kidney Injury/mortality',
#  'Acute Kidney Injury/mortality*',
#  'Acute Kidney Injury/physiopathology',
#  'Adolescent',
#  'Adult',
#  'African Americans/statistics & numerical data',
#  'Age Factors',
#  'Aged',
#  'Aged, 80 and over',
#  'Airway Extubation/statistics & numerical data*',
#  'Alanine Transaminase/blood',
#  'Alcoholism/mortality*',
#  'Algorithms',
#  'Algorithms*',
#  'Anti-Bacterial Agents/therapeutic use',
#  'Antipyretics/adverse effects*',
#  'Antipyretics/therapeutic use*',
#  'Area Under Curve',
#  'Arrhythmias, Cardiac/diagnosis',
#  'Arrhythmias, Cardiac/diagnosis*',
#  'Arrhythmias, Cardiac/physiopathology*',
#  'Arterial Pressure',
#  'Artifacts',
#  'Artificial Intelligence',
#  'Artificial Intelligence*',
#  'Asian Americans/statistics & numerical data',
#  'Bayes Theorem',
#  'Bilirubin/blood',
#  'Biomarkers',
#  'Biomarkers/blood',
#  'Biomedical Engineering/methods',
#  'Biomedical Research',
#  'Biomedical Research*',
#  'Blood Glucose/analysis*',
#  'Blood Pressure',
#  'Blood Pressure Determination/methods*',
#  'Blood Pressure/physiology',
#  'Blood Pressure/physiology*',
#  'Body Mass Index',
#  'Body Temperature/drug effects*',
#  'Body Temperature/physiology',
#  'Boston',
#  'Boston/epidemiology',
#  'Brain Injuries/epidemiology',
#  'Brain Ischemia/classification',
#  'Calcium/chemistry*',
#  'Calcium/metabolism*',
#  'Cardiology/methods',
#  'Cell Count',
#  'Child',
#  'Child, Preschool',
#  'Circadian Rhythm',
#  'Classification/methods*',
#  'Clinical Alarms*',
#  'Clinical Coding/methods*',
#  'Clinical Laboratory Techniques/standards*',
#  'Clostridium Infections/drug therapy',
#  'Clostridium Infections/immunology*',
#  'Clostridium difficile*',
#  'Cluster Analysis',
#  'Cohort Studies',
#  'Comorbidity',
#  'Computational Biology',
#  'Computational Biology/methods',
#  'Computer Simulation',
#  'Computer Simulation*',
#  'Continental Population Groups/statistics & numerical data*',
#  'Costs and Cost Analysis*',
#  'Creatinine/blood',
#  'Critical Care',
#  'Critical Care*',
#  'Critical Care/methods',
#  'Critical Care/methods*',
#  'Critical Care/statistics & numerical data*',
#  'Critical Illness',
#  'Critical Illness/classification*',
#  'Critical Illness/mortality',
#  'Critical Illness/mortality*',
#  'Critical Illness/therapy*',
#  'Cross Infection/diagnosis*',
#  'Cross-Sectional Studies',
#  'Cryotherapy/adverse effects',
#  'Data Interpretation, Statistical',
#  'Data Mining',
#  'Data Mining*',
#  'Data Mining/methods',
#  'Data Mining/methods*',
#  'Data Mining/statistics & numerical data*',
#  'Database Management Systems',
#  'Databases, Factual',
#  'Databases, Factual*',
#  'Databases, Factual/statistics & numerical data',
#  'Databases, Factual/statistics & numerical data*',
#  'Datasets as Topic',
#  'Decision Making, Computer-Assisted',
#  'Decision Making, Computer-Assisted*',
#  'Decision Support Systems, Clinical',
#  'Decision Support Systems, Clinical*',
#  'Decision Support Systems, Management*',
#  'Decision Support Techniques*',
#  'Decision Trees',
#  'Delayed Diagnosis',
#  'Demography',
#  'Diabetic Ketoacidosis/blood*',
#  'Diabetic Ketoacidosis/mortality*',
#  'Diagnosis, Computer-Assisted/methods',
#  'Diagnosis, Computer-Assisted/methods*',
#  'Diagnostic Errors/prevention & control*',
#  'Disseminated Intravascular Coagulation*',
#  'Dose-Response Relationship, Drug',
#  'Early Diagnosis*',
#  'Electrocardiography',
#  'Electrocardiography*',
#  'Electrocardiography/instrumentation*',
#  'Electrocardiography/methods*',
#  'Electronic Data Processing',
#  'Electronic Health Records',
#  'Electronic Health Records*',
#  'Electronic Health Records*/classification',
#  'Electronic Health Records/classification*',
#  'Electronic Health Records/organization & administration*',
#  'Electronic Health Records/standards',
#  'Electronic Health Records/statistics & numerical data',
#  'Electronic Health Records/statistics & numerical data*',
#  'Equipment Failure*',
#  'Erythrocyte Indices*',
#  'Erythrocyte Volume*',
#  'European Continental Ancestry Group/statistics & numerical data',
#  'Evaluation Studies as Topic',
#  'Expert Systems',
#  'Expert Systems*',
#  'False Positive Reactions',
#  'Female',
#  'Fever/drug therapy*',
#  'Fever/etiology',
#  'Fluid Therapy*',
#  'Forecasting',
#  'Fourier Analysis',
#  'Fuzzy Logic',
#  'Fuzzy Logic*',
#  'Genomics',
#  'Health Information Exchange/standards*',
#  'Health Information Interoperability/standards',
#  'Health Level Seven',
#  'Health Status',
#  'Health Status Disparities*',
#  'Health Status Indicators',
#  'Health Status Indicators*',
#  'Heart Failure/diagnosis*',
#  'Heart Failure/etiology',
#  'Heart Failure/physiopathology*',
#  'Heart Function Tests/methods*',
#  'Heart Rate',
#  'Heart Rate*',
#  'Heart Rate/physiology',
#  'Heart Rate/physiology*',
#  'Heart Ventricles/pathology',
#  'Heart Ventricles/physiopathology',
#  'Heart/physiology*',
#  'Hemodynamics',
#  'Hemodynamics*',
#  'Hemodynamics/physiology*',
#  'Heparin/administration & dosage*',
#  'Heparin/pharmacology*',
#  'Hepatitis/blood*',
#  'Hepatitis/mortality',
#  'Hepatitis/physiopathology',
#  'Hospital Mortality',
#  'Hospital Mortality*',
#  'Hospital Mortality/ethnology*',
#  'Humans',
#  'Hyperglycemia/diagnosis',
#  'Hyperlactatemia*',
#  'Hypoglycemia/diagnosis',
#  'Hypotension/diagnosis*',
#  'Hypotension/physiopathology',
#  'Hypotension/physiopathology*',
#  'Hypotension/prevention & control*',
#  'Hypovolemia*',
#  'Hypoxia/blood*',
#  'Hypoxia/mortality',
#  'Hypoxia/physiopathology',
#  'Iatrogenic Disease',
#  'Incidence',
#  'Infant',
#  'Infant, Newborn',
#  'Infant, Newborn*',
#  'Information Storage and Retrieval',
#  'Information Storage and Retrieval*',
#  'Information Storage and Retrieval/methods',
#  'Information Storage and Retrieval/methods*',
#  'Information Storage and Retrieval/statistics & numerical data*',
#  'Information Systems',
#  'Information Theory*',
#  'Intensive Care Units',
#  'Intensive Care Units*',
#  'Intensive Care Units*/organization & administration',
#  'Intensive Care Units, Pediatric',
#  'Intensive Care Units/organization & administration',
#  'Intensive Care Units/organization & administration*',
#  'Intensive Care Units/standards*',
#  'Intensive Care Units/statistics & numerical data',
#  'Intensive Care Units/statistics & numerical data*',
#  'International Classification of Diseases',
#  'International Classification of Diseases*',
#  'International Normalized Ratio',
#  'Internet',
#  'Intubation',
#  'Isotonic Solutions/administration & dosage*',
#  'Jaundice, Neonatal/classification',
#  'Jaundice, Neonatal/diagnosis',
#  'Kaplan-Meier Estimate',
#  'Knowledge Bases',
#  'L-Lactate Dehydrogenase/blood',
#  'Learning*',
#  'Least-Squares Analysis',
#  'Length of Stay',
#  'Leukocyte Count*',
#  'Leukocytosis/etiology',
#  'Linear Models',
#  'Linguistics',
#  'Liver Cirrhosis/blood',
#  'Liver Cirrhosis/complications',
#  'Liver Cirrhosis/diagnosis',
#  'Liver Cirrhosis/diagnosis*',
#  'Liver Cirrhosis/mortality*',
#  'Liver Failure/blood',
#  'Liver Failure/diagnosis*',
#  'Liver Failure/etiology',
#  'Liver Failure/mortality*',
#  'Logistic Models',
#  'Longitudinal Studies',
#  'Lymphocyte Count',
#  'Lymphocytes/cytology*',
#  'Machine Learning',
#  'Machine Learning*',
#  'Machine Learning/statistics & numerical data*',
#  'Male',
#  'Markov Chains',
#  'Markov Chains*',
#  'Massachusetts',
#  'Massachusetts/epidemiology',
#  'Medical Informatics',
#  'Medical Informatics Applications',
#  'Medical Informatics Applications*',
#  'Medical Informatics*',
#  'Medical Informatics/methods',
#  'Medical Informatics/methods*',
#  'Medical Records',
#  'Medical Records Systems, Computerized',
#  'Middle Aged',
#  'Models, Biological',
#  'Models, Biological*',
#  'Models, Cardiovascular*',
#  'Models, Statistical',
#  'Models, Statistical*',
#  'Models, Theoretical',
#  'Models, Theoretical*',
#  'Monitoring, Ambulatory/methods*',
#  'Monitoring, Physiologic',
#  'Monitoring, Physiologic*',
#  'Monitoring, Physiologic/instrumentation*',
#  'Monitoring, Physiologic/methods*',
#  'Mortality',
#  'Mortality*',
#  'Mothers*',
#  'Multiple Myeloma/complications*',
#  'Multiple Myeloma/genetics',
#  'Multiple Myeloma/therapy',
#  'Multiple Organ Failure',
#  'Multiple Organ Failure/blood',
#  'Multiple Organ Failure/diagnosis*',
#  'Multiple Organ Failure/etiology',
#  'Multiple Organ Failure/mortality*',
#  'Multiple Organ Failure/physiopathology*',
#  'Multivariate Analysis',
#  'Natural Language Processing',
#  'Natural Language Processing*',
#  'Neural Networks (Computer)',
#  'Neural Networks (Computer)*',
#  'Neutrophils/cytology*',
#  'New York',
#  'New York/epidemiology',
#  'Nonlinear Dynamics',
#  'Norepinephrine/antagonists & inhibitors*',
#  'Nurses',
#  'Nursing Records*',
#  'Obesity/complications',
#  'Obesity/mortality*',
#  'Organ Dysfunction Scores',
#  'Organ Dysfunction Scores*',
#  'Outcome Assessment (Health Care)',
#  'Overweight/complications',
#  'Overweight/mortality*',
#  'Oxygen/metabolism',
#  'Pancreatitis/blood*',
#  'Pancreatitis/diagnosis*',
#  'Pancreatitis/etiology',
#  'Pancreatitis/mortality*',
#  'Pancreatitis/therapy*',
#  'Partial Pressure',
#  'Patient Admission',
#  'Patient Admission*',
#  'Patient Discharge',
#  'Patient Discharge*',
#  'Patient Readmission*',
#  'Patient Readmission/statistics & numerical data*',
#  'Patient-Specific Modeling*',
#  'Pattern Recognition, Automated',
#  'Pattern Recognition, Automated*',
#  'Pattern Recognition, Automated/methods',
#  'Pattern Recognition, Automated/methods*',
#  'Phenotype*',
#  'Photoplethysmography',
#  'Photoplethysmography/methods*',
#  'Phototherapy/statistics & numerical data',
#  'Pilot Projects',
#  'Platelet Count',
#  'Plethysmography*',
#  'Postoperative Complications/diagnosis*',
#  'Postoperative Complications/epidemiology*',
#  'Predictive Value of Tests',
#  'Pressure',
#  'Principal Component Analysis',
#  'Probability',
#  'Prognosis',
#  'Programming Languages',
#  'Proportional Hazards Models',
#  'Prospective Studies',
#  'Quality Assurance, Health Care',
#  'Quality Control',
#  'ROC Curve',
#  'Reference Values',
#  'Regression Analysis',
#  'Regression Analysis*',
#  'Reinforcement (Psychology)*',
#  'Reproducibility of Results',
#  'Research*',
#  'Respiration Disorders/diagnosis*',
#  'Respiration Disorders/mortality',
#  'Respiration Disorders/mortality*',
#  'Respiration Disorders/physiopathology*',
#  'Respiration, Artificial*',
#  'Respiration, Artificial/statistics & numerical data',
#  'Respiration, Artificial/statistics & numerical data*',
#  'Respiratory Distress Syndrome, Adult/diagnosis*',
#  'Respiratory Distress Syndrome, Adult/epidemiology*',
#  'Respiratory Distress Syndrome, Newborn/diagnosis*',
#  'Respiratory Distress Syndrome, Newborn/epidemiology',
#  'Respiratory Distress Syndrome, Newborn/rehabilitation*',
#  'Respiratory Insufficiency/diagnosis',
#  'Respiratory Insufficiency/mortality*',
#  'Respiratory Rate/physiology',
#  'Respiratory Rate/physiology*',
#  'Resuscitation*',
#  'Resuscitation/methods*',
#  'Retrospective Studies',
#  "Ringer's Lactate",
#  'Risk',
#  'Risk Assessment',
#  'Risk Assessment*',
#  'Risk Assessment/methods',
#  'Risk Assessment/methods*',
#  'Risk Factors',
#  'Sensitivity and Specificity',
#  'Sepsis',
#  'Sepsis/complications*',
#  'Sepsis/diagnosis',
#  'Sepsis/diagnosis*',
#  'Sepsis/drug therapy*',
#  'Sepsis/epidemiology',
#  'Sepsis/mortality',
#  'Sepsis/mortality*',
#  'Sepsis/pathology*',
#  'Sepsis/physiopathology*',
#  'Sepsis/therapy*',
#  'Serotonin Uptake Inhibitors/therapeutic use*',
#  'Severity of Illness Index',
#  'Severity of Illness Index*',
#  'Shock, Septic',
#  'Shock, Septic*',
#  'Shock, Septic/mortality*',
#  'Shock, Septic/physiopathology',
#  'Signal Processing, Computer-Assisted',
#  'Signal Processing, Computer-Assisted*',
#  'Sodium Chloride/administration & dosage*',
#  'Software',
#  'Software*',
#  'Stroke Volume*',
#  'Subarachnoid Hemorrhage/blood',
#  'Subarachnoid Hemorrhage/diagnosis*',
#  'Subarachnoid Hemorrhage/physiopathology*',
#  'Subarachnoid Hemorrhage/therapy',
#  'Supervised Machine Learning/statistics & numerical data',
#  'Support Vector Machine*',
#  'Support Vector Machine/economics*',
#  'Survival Analysis',
#  'Systematized Nomenclature of Medicine',
#  'Tachycardia, Ventricular/diagnosis*',
#  'Tachycardia, Ventricular/physiopathology*',
#  'Terminology as Topic',
#  'Tertiary Care Centers',
#  'Therapeutics',
#  'Therapeutics/adverse effects*',
#  'Tilt-Table Test',
#  'Time',
#  'Time Factors',
#  'Treatment Failure',
#  'Triage/methods',
#  'Triage/methods*',
#  'Unified Medical Language System',
#  'Unified Medical Language System*',
#  'United Kingdom',
#  'United States',
#  'Unnecessary Procedures/standards*',
#  'Unsupervised Machine Learning/statistics & numerical data',
#  'User-Computer Interface',
#  'User-Computer Interface*',
#  'Vasoconstrictor Agents*/administration & dosage',
#  'Vasoconstrictor Agents*/therapeutic use',
#  'Vasoconstrictor Agents/therapeutic use',
#  'Ventricular Function, Left*',
#  'Ventricular Premature Complexes/diagnosis*',
#  'Vital Signs',
#  'Vital Signs/physiology',
#  'Wavelet Analysis',
#  'Young Adult'}

# %%
print(len(all_mesh_terms))
print(len(set(all_mesh_terms)))
# Out:
# 1028
# 432

# %%
# Clean the mesh terms. Strip the * and remove things after /
for i in range(len(all_mesh_terms)):
    all_mesh_terms[i] = all_mesh_terms[i].strip('*').split('/')[0]

print('Total mesh terms:', len(all_mesh_terms))
print('Unique mesh terms:', len(set(all_mesh_terms)))
# Out:
# Total mesh terms: 1028
# Unique mesh terms: 258

# %%
# Generating figures
mesh_text = ' '.join(term for term in all_mesh_terms)
wordcloud = WordCloud(width=1920, height=1080, background_color="white").generate(mesh_text)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
all_mesh_terms
# Out:
# ['Aged',
#  'Aged, 80 and over',
#  'Algorithms',
#  'Boston',
#  'Female',
#  'Hospital Mortality',
#  'Humans',
#  'Intensive Care Units',
#  'Machine Learning',
#  'Male',
#  'Middle Aged',
#  'ROC Curve',
#  'Reproducibility of Results',
#  'Risk',
#  'Severity of Illness Index',
#  'Acute Disease',
#  'Aged',
#  'Databases, Factual',
#  'Erythrocyte Indices',
#  'Female',
#  'Humans',
#  'Intensive Care Units',
#  'Male',
#  'Middle Aged',
#  'Multivariate Analysis',
#  'Pancreatitis',
#  'Pancreatitis',
#  'Prognosis',
#  'Retrospective Studies',
#  'Academic Medical Centers',
#  'Adult',
#  'African Americans',
#  'Aged',
#  'Aged, 80 and over',
#  'Asian Americans',
#  'Boston',
#  'Continental Population Groups',
#  'Electronic Health Records',
#  'European Continental Ancestry Group',
#  'Female',
#  'Health Status Disparities',
#  'Hospital Mortality',
#  'Humans',
#  'Intensive Care Units',
#  'Male',
#  'Middle Aged',
#  'Retrospective Studies',
#  'Adult',
#  'Artificial Intelligence',
#  'Critical Care',
#  'Databases, Factual',
#  'Decision Support Systems, Clinical',
#  'Expert Systems',
#  'Female',
#  'Humans',
#  'Intensive Care Units',
#  'Medical Informatics Applications',
#  'Medical Records Systems, Computerized',
#  'Monitoring, Physiologic',
#  'Quality Control',
#  'Retrospective Studies',
#  'United States',
#  'Algorithms',
#  'Databases, Factual',
#  'Humans',
#  'Intensive Care Units',
#  'Intubation',
#  'Pressure',
#  'Respiration, Artificial',
#  'Time Factors',
#  'Access to Information',
#  'Biomedical Research',
#  'Critical Care',
#  'Databases, Factual',
#  'Humans',
#  'Internet',
#  'Software',
#  'User-Computer Interface',
#  'Aged',
#  'Critical Care',
#  'Databases, Factual',
#  'Female',
#  'Hospital Mortality',
#  'Humans',
#  'Intensive Care Units',
#  'Male',
#  'Middle Aged',
#  'Norepinephrine',
#  'Patient Admission',
#  'Retrospective Studies',
#  'Serotonin Uptake Inhibitors',
#  'Blood Pressure',
#  'Circadian Rhythm',
#  'Critical Care',
#  'Data Mining',
#  'Databases, Factual',
#  'Heart Rate',
#  'Humans',
#  'Medical Informatics',
#  'Aged',
#  'Cell Count',
#  'Erythrocyte Volume',
#  'Female',
#  'Humans',
#  'Intensive Care Units',
#  'Lymphocytes',
#  'Male',
#  'Middle Aged',
#  'Neutrophils',
#  'Patient Admission',
#  'Prognosis',
#  'Retrospective Studies',
#  'Subarachnoid Hemorrhage',
#  'Subarachnoid Hemorrhage',
#  'Subarachnoid Hemorrhage',
#  'Subarachnoid Hemorrhage',
#  'Adult',
#  'Classification',
#  'Electronic Health Records*',
#  'Humans',
#  'Infant, Newborn',
#  'Information Storage and Retrieval',
#  'Intensive Care Units',
#  'Jaundice, Neonatal',
#  'Jaundice, Neonatal',
#  'Phototherapy',
#  'Respiration, Artificial',
#  'Support Vector Machine',
#  'Aged',
#  'Calcium',
#  'Calcium',
#  'Critical Illness',
#  'Databases, Factual',
#  'Female',
#  'Humans',
#  'Intensive Care Units',
#  'Logistic Models',
#  'Male',
#  'Medical Informatics',
#  'Middle Aged',
#  'Predictive Value of Tests',
#  'Blood Pressure',
#  'Critical Care',
#  'Forecasting',
#  'Heart Rate',
#  'Humans',
#  'Intensive Care Units',
#  'Machine Learning',
#  'Multiple Organ Failure',
#  'Risk Assessment',
#  'Shock, Septic',
#  'Critical Care',
#  'Databases, Factual',
#  'Humans',
#  'Hyperlactatemia',
#  'Intensive Care Units',
#  'Sepsis',
#  'Shock, Septic',
#  'Adult',
#  'Aged',
#  'Aged, 80 and over',
#  'Databases, Factual',
#  'Demography',
#  'Female',
#  'Humans',
#  'Intensive Care Units',
#  'Linear Models',
#  'Male',
#  'Middle Aged',
#  'Models, Biological',
#  'Probability',
#  'Sepsis',
#  'Sepsis',
#  'Signal Processing, Computer-Assisted',
#  'Adult',
#  'Aged',
#  'Aged, 80 and over',
#  'Body Mass Index',
#  'Boston',
#  'Cohort Studies',
#  'Critical Illness',
#  'Female',
#  'Humans',
#  'Intensive Care Units',
#  'Male',
#  'Middle Aged',
#  'Obesity',
#  'Obesity',
#  'Overweight',
#  'Overweight',
#  'Proportional Hazards Models',
#  'Risk Factors',
#  'Severity of Illness Index',
#  'Survival Analysis',
#  'Databases, Factual',
#  'Electronic Health Records',
#  'Humans',
#  'Medical Informatics Applications',
#  'Clinical Laboratory Techniques',
#  'Databases, Factual',
#  'Humans',
#  'Information Theory',
#  'Intensive Care Units',
#  'Unnecessary Procedures',
#  'Access to Information',
#  'Adult',
#  'Critical Care',
#  'Databases, Factual',
#  'Humans',
#  'Monitoring, Physiologic',
#  'Research',
#  'Wavelet Analysis',
#  'Algorithms',
#  'Blood Pressure',
#  'Data Mining',
#  'Humans',
#  'Hypotension',
#  'Hypotension',
#  'Intensive Care Units',
#  'Pattern Recognition, Automated',
#  'Risk Factors',
#  'Algorithms',
#  'Biomarkers',
#  'Databases, Factual',
#  'Fuzzy Logic',
#  'Heart Failure',
#  'Heart Failure',
#  'Heart Failure',
#  'Hemodynamics',
#  'Humans',
#  'Intensive Care Units',
#  'Models, Theoretical',
#  'Patient Admission',
#  'Prognosis',
#  'Retrospective Studies',
#  'Severity of Illness Index',
#  'Stroke Volume',
#  'Ventricular Function, Left',
#  'Algorithms',
#  'Artifacts',
#  'Critical Care',
#  'Humans',
#  'Hypovolemia',
#  'Photoplethysmography',
#  'Signal Processing, Computer-Assisted',
#  'Boston',
#  'Critical Care',
#  'Electronic Health Records',
#  'Humans',
#  'Intensive Care Units*',
#  'Middle Aged',
#  'Prognosis',
#  'Quality Assurance, Health Care',
#  'Reproducibility of Results',
#  'Retrospective Studies',
#  'Severity of Illness Index',
#  'Data Mining',
#  'Electronic Health Records',
#  'Humans',
#  'Intensive Care Units',
#  'Medical Informatics Applications',
#  'Nurses',
#  'Regression Analysis',
#  'Risk Assessment',
#  'Acute Kidney Injury',
#  'Critical Care',
#  'Hospital Mortality',
#  'Humans',
#  'Intensive Care Units',
#  'Prognosis',
#  'ROC Curve',
#  'Sensitivity and Specificity',
#  'Support Vector Machine',
#  'Fuzzy Logic',
#  'Humans',
#  'Intensive Care Units',
#  'Monitoring, Physiologic',
#  'Risk Assessment',
#  'Algorithms',
#  'Critical Care',
#  'Critical Illness',
#  'Data Mining',
#  'Data Mining',
#  'Databases, Factual',
#  'Humans',
#  'Information Storage and Retrieval',
#  'Information Storage and Retrieval',
#  'Intensive Care Units',
#  'Models, Theoretical',
#  'Programming Languages',
#  'Reproducibility of Results',
#  'Computational Biology',
#  'Critical Care',
#  'Databases, Factual',
#  'Electronic Health Records',
#  'Female',
#  'Humans',
#  'Machine Learning',
#  'Male',
#  'Supervised Machine Learning',
#  'Unsupervised Machine Learning',
#  'Algorithms',
#  'Clinical Alarms',
#  'Critical Care',
#  'Diagnosis, Computer-Assisted',
#  'Diagnostic Errors',
#  'Electrocardiography',
#  'False Positive Reactions',
#  'Humans',
#  'Intensive Care Units',
#  'Pattern Recognition, Automated',
#  'Reproducibility of Results',
#  'Sensitivity and Specificity',
#  'Tachycardia, Ventricular',
#  'Wavelet Analysis',
#  'Artificial Intelligence',
#  'Boston',
#  'Decision Making, Computer-Assisted',
#  'Female',
#  'Fluid Therapy',
#  'Humans',
#  'Information Storage and Retrieval',
#  'Intensive Care Units',
#  'Male',
#  'Vasoconstrictor Agents',
#  'Adult',
#  'Aged',
#  'Algorithms',
#  'Computational Biology',
#  'Disseminated Intravascular Coagulation',
#  'Electronic Health Records',
#  'Female',
#  'Humans',
#  'Information Storage and Retrieval',
#  'Male',
#  'Middle Aged',
#  'Patient-Specific Modeling',
#  'Prospective Studies',
#  'Retrospective Studies',
#  'Software',
#  'Artificial Intelligence',
#  'Databases, Factual',
#  'Decision Support Systems, Clinical',
#  'Expert Systems',
#  'Humans',
#  'Information Systems',
#  'Intensive Care Units',
#  'Medical Records Systems, Computerized',
#  'Monitoring, Physiologic',
#  'Signal Processing, Computer-Assisted',
#  'Software',
#  'Acute Disease',
#  'Algorithms',
#  'Databases, Factual',
#  'Diagnosis, Computer-Assisted',
#  'Humans',
#  'Hypotension',
#  'Hypotension',
#  'Intensive Care Units',
#  'Neural Networks (Computer)',
#  'Predictive Value of Tests',
#  'Regression Analysis',
#  'Reproducibility of Results',
#  'Signal Processing, Computer-Assisted',
#  'Humans',
#  'Intensive Care Units',
#  'Logistic Models',
#  'Natural Language Processing',
#  'Resuscitation',
#  'Adult',
#  'Algorithms',
#  'Brain Injuries',
#  'Child',
#  'Critical Care',
#  'Databases, Factual',
#  'Hospital Mortality',
#  'Humans',
#  'Intensive Care Units',
#  'Intensive Care Units, Pediatric',
#  'Medical Informatics',
#  'Models, Statistical',
#  'Outcome Assessment (Health Care)',
#  'Predictive Value of Tests',
#  'Prognosis',
#  'ROC Curve',
#  'Regression Analysis',
#  'Risk Assessment',
#  'Access to Information',
#  'Biomedical Research',
#  'Comorbidity',
#  'Critical Care',
#  'Data Mining',
#  'Databases, Factual',
#  'Electronic Health Records',
#  'Humans',
#  'Organ Dysfunction Scores',
#  'ROC Curve',
#  'Reproducibility of Results',
#  'Sepsis',
#  'Severity of Illness Index',
#  'Therapeutics',
#  'Algorithms',
#  'Databases, Factual',
#  'Humans',
#  'Intensive Care Units',
#  'Acute Disease',
#  'Aged',
#  'Critical Illness',
#  'Databases, Factual',
#  'Female',
#  'Humans',
#  'Intensive Care Units',
#  'Isotonic Solutions',
#  'Logistic Models',
#  'Male',
#  'Massachusetts',
#  'Middle Aged',
#  'Pancreatitis',
#  'Pancreatitis',
#  'Pancreatitis',
#  'Resuscitation',
#  'Retrospective Studies',
#  "Ringer's Lactate",
#  'Sodium Chloride',
#  'Adult',
#  'Aged',
#  'Area Under Curve',
#  'Cross-Sectional Studies',
#  'Female',
#  'Humans',
#  'Intensive Care Units',
#  'Machine Learning',
#  'Male',
#  'Middle Aged',
#  'Patient Readmission',
#  'ROC Curve',
#  'Retrospective Studies',
#  'Tertiary Care Centers',
#  'United Kingdom',
#  'Adult',
#  'Algorithms',
#  'Area Under Curve',
#  'Hospital Mortality',
#  'Humans',
#  'Intensive Care Units',
#  'Models, Theoretical',
#  'Natural Language Processing',
#  'Nursing Records',
#  'Risk Assessment',
#  'Severity of Illness Index',
#  'Unified Medical Language System',
#  'Adult',
#  'Aged',
#  'Critical Illness',
#  'Diabetic Ketoacidosis',
#  'Diabetic Ketoacidosis',
#  'Female',
#  'Humans',
#  'Intensive Care Units',
#  'Kaplan-Meier Estimate',
#  'Longitudinal Studies',
#  'Lymphocyte Count',
#  'Male',
#  'Middle Aged',
#  'Patient Readmission',
#  'Platelet Count',
#  'Predictive Value of Tests',
#  'Prognosis',
#  'Retrospective Studies',
#  'Time Factors',
#  'Airway Extubation',
#  'Algorithms',
#  'Artificial Intelligence',
#  'Database Management Systems',
#  'Databases, Factual',
#  'Decision Support Systems, Management',
#  'Diagnosis, Computer-Assisted',
#  'Female',
#  'Humans',
#  'Incidence',
#  'Infant, Newborn',
#  'Male',
#  'New York',
#  'Prognosis',
#  'Reproducibility of Results',
#  'Respiration, Artificial',
#  'Respiratory Distress Syndrome, Newborn',
#  'Respiratory Distress Syndrome, Newborn',
#  'Respiratory Distress Syndrome, Newborn',
#  'Risk Assessment',
#  'Sensitivity and Specificity',
#  'Treatment Failure',
#  'Critical Care',
#  'Humans',
#  'Intensive Care Units',
#  'Length of Stay',
#  'Logistic Models',
#  'Patient Readmission',
#  'Retrospective Studies',
#  'Algorithms',
#  'Blood Pressure',
#  'Heart Rate',
#  'Hemodynamics',
#  'Humans',
#  'Intensive Care Units',
#  'Monitoring, Physiologic',
#  'Multiple Organ Failure',
#  'Multiple Organ Failure',
#  'Neural Networks (Computer)',
#  'ROC Curve',
#  'Regression Analysis',
#  'Reproducibility of Results',
#  'Sensitivity and Specificity',
#  'Software',
#  'Time Factors',
#  'Humans',
#  'Hypotension',
#  'Intensive Care Units',
#  'Nonlinear Dynamics',
#  'Software',
#  'Heart Rate',
#  'Humans',
#  'Intensive Care Units',
#  'Internet',
#  'Sepsis',
#  'Sepsis',
#  'User-Computer Interface',
#  'Vital Signs',
#  'Algorithms',
#  'Decision Trees',
#  'Female',
#  'Hospital Mortality',
#  'Humans',
#  'Intensive Care Units',
#  'Logistic Models',
#  'Male',
#  'Multivariate Analysis',
#  'Respiration Disorders',
#  'Respiration, Artificial',
#  'Time Factors',
#  'Adult',
#  'Blood Pressure',
#  'Critical Care',
#  'Humans',
#  'Monitoring, Physiologic',
#  'Vasoconstrictor Agents*',
#  'Vasoconstrictor Agents*',
#  'Aged',
#  'Algorithms',
#  'Critical Care',
#  'Critical Illness',
#  'Electronic Data Processing',
#  'Female',
#  'Health Status',
#  'Humans',
#  'Intensive Care Units',
#  'Least-Squares Analysis',
#  'Linear Models',
#  'Machine Learning',
#  'Male',
#  'Medical Informatics',
#  'Middle Aged',
#  'Monitoring, Ambulatory',
#  'Principal Component Analysis',
#  'Reproducibility of Results',
#  'Sensitivity and Specificity',
#  'Signal Processing, Computer-Assisted',
#  'Vital Signs',
#  'Adult',
#  'Algorithms',
#  'Blood Pressure',
#  'Databases, Factual',
#  'Female',
#  'Health Status Indicators',
#  'Heart Rate',
#  'Hospital Mortality',
#  'Humans',
#  'Intensive Care Units',
#  'Male',
#  'Medical Informatics',
#  'Models, Statistical',
#  'Monitoring, Physiologic',
#  'Prognosis',
#  'Reproducibility of Results',
#  'Tilt-Table Test',
#  'Adult',
#  'Datasets as Topic',
#  'Decision Making, Computer-Assisted',
#  'Decision Support Systems, Clinical',
#  'Humans',
#  'Intensive Care Units',
#  'Length of Stay',
#  'Patient Discharge',
#  'Prognosis',
#  'ROC Curve',
#  'Retrospective Studies',
#  'Risk Assessment',
#  'Risk Factors',
#  'Triage',
#  'Data Mining',
#  'Databases, Factual',
#  'Humans',
#  'Intensive Care Units',
#  'Regression Analysis',
#  'Support Vector Machine',
#  'Critical Care',
#  'Databases, Factual',
#  'Humans',
#  'Medical Records',
#  'Nurses',
#  'Postoperative Complications',
#  'Postoperative Complications',
#  'Respiratory Distress Syndrome, Adult',
#  'Respiratory Distress Syndrome, Adult',
#  'Respiratory Rate',
#  'Risk',
#  'Adult',
#  'Critical Illness',
#  'Cross Infection',
#  'Electronic Health Records',
#  'Humans',
#  'Iatrogenic Disease',
#  'Intensive Care Units',
#  'International Classification of Diseases',
#  'Phenotype',
#  'Time',
#  'Critical Care',
#  'Data Interpretation, Statistical',
#  'Hemodynamics',
#  'Humans',
#  'Hypotension',
#  'Hypotension',
#  'Pattern Recognition, Automated',
#  'Regression Analysis',
#  'Acute Disease',
#  'Algorithms',
#  'Blood Pressure',
#  'Databases, Factual',
#  'Early Diagnosis',
#  'Humans',
#  'Intensive Care Units',
#  'Models, Theoretical',
#  'Sensitivity and Specificity',
#  'Anti-Bacterial Agents',
#  'Clostridium Infections',
#  'Clostridium Infections',
#  'Clostridium difficile',
#  'Critical Illness',
#  'Delayed Diagnosis',
#  'Electronic Health Records',
#  'Genomics',
#  'Humans',
#  'Intensive Care Units',
#  'International Classification of Diseases',
#  'Leukocyte Count',
#  'Leukocytosis',
#  'Medical Records Systems, Computerized',
#  'Phenotype',
#  'Reference Values',
#  'Acute Disease',
#  'Algorithms',
#  'Biomedical Engineering',
#  'Blood Pressure',
#  'Cardiology',
#  'Humans',
#  'Hypotension',
#  'Hypotension',
#  'Neural Networks (Computer)',
#  'Signal Processing, Computer-Assisted',
#  'Software',
#  'Time Factors',
#  'Adolescent',
#  'Adult',
#  'Aged',
#  'Algorithms',
#  'Child',
#  'Child, Preschool',
#  'Electrocardiography',
#  'Fourier Analysis',
#  'Humans',
#  'Infant',
#  'Intensive Care Units',
#  'Middle Aged',
#  'Plethysmography',
#  'Respiratory Rate',
#  'Signal Processing, Computer-Assisted',
#  'Young Adult',
#  'Algorithms',
#  'Critical Care',
#  'Decision Support Systems, Clinical',
#  'Diagnosis, Computer-Assisted',
#  'Hypotension',
#  'Monitoring, Physiologic',
#  'Multiple Organ Failure',
#  'New York',
#  'Prognosis',
#  'Reproducibility of Results',
#  'Sensitivity and Specificity',
#  'Algorithms',
#  'Hospital Mortality',
#  'Humans',
#  'Intensive Care Units',
#  'Markov Chains',
#  'Monitoring, Physiologic',
#  'Oxygen',
#  'Partial Pressure',
#  'Pattern Recognition, Automated',
#  'Respiration Disorders',
#  'Respiration Disorders',
#  'Respiration Disorders',
#  'Respiratory Rate',
#  'Algorithms',
#  'Databases, Factual',
#  'False Positive Reactions',
#  'Heart',
#  'Heart Function Tests',
#  'Heart Rate',
#  'Humans',
#  'Sensitivity and Specificity',
#  'Software',
#  'Adult',
#  'Aged',
#  'Aged, 80 and over',
#  'Antipyretics',
#  'Antipyretics',
#  'Body Temperature',
#  'Body Temperature',
#  'Critical Care',
#  'Critical Illness',
#  'Cryotherapy',
#  'Databases, Factual',
#  'Female',
#  'Humans',
#  'Male',
#  'Middle Aged',
#  'Multivariate Analysis',
#  'Probability',
#  'Risk Factors',
#  'Sepsis',
#  'Sepsis',
#  'Sepsis',
#  'Computer Simulation',
#  'Decision Support Techniques',
#  'Electronic Health Records',
#  'Humans',
#  'Models, Statistical',
#  'Phenotype',
#  'Algorithms',
#  'Blood Pressure Determination',
#  'Computer Simulation',
#  'Critical Care',
#  'Diagnosis, Computer-Assisted',
#  'Electrocardiography',
#  'Humans',
#  'Hypotension',
#  'Models, Cardiovascular',
#  'Reproducibility of Results',
#  'Risk Assessment',
#  'Risk Factors',
#  'Sensitivity and Specificity',
#  'Acute Kidney Injury',
#  'Acute Kidney Injury',
#  'Acute Kidney Injury',
#  'Adult',
#  'Age Factors',
#  'Aged',
#  'Alanine Transaminase',
#  'Bilirubin',
#  'Biomarkers',
#  'Critical Illness',
#  'Female',
#  'Hepatitis',
#  'Hepatitis',
#  'Hepatitis',
#  'Hospital Mortality',
#  'Humans',
#  'Hypoxia',
#  'Hypoxia',
#  'Hypoxia',
#  'L-Lactate Dehydrogenase',
#  'Male',
#  'Middle Aged',
#  'Predictive Value of Tests',
#  'Retrospective Studies',
#  'Risk Factors',
#  'Vasoconstrictor Agents',
#  'Adult',
#  'Aged',
#  'Aged, 80 and over',
#  'Critical Care',
#  'Critical Illness',
#  'Electronic Health Records',
#  'Hospital Mortality',
#  'Humans',
#  'Medical Informatics',
#  'Middle Aged',
#  'ROC Curve',
#  'Regression Analysis',
#  'Sepsis',
#  'Sepsis',
#  'Sepsis',
#  'Young Adult',
#  'Equipment Failure',
#  'Humans',
#  'Information Storage and Retrieval',
#  'Monitoring, Physiologic',
#  'Algorithms',
#  'Arrhythmias, Cardiac',
#  'Artificial Intelligence',
#  'Blood Pressure Determination',
#  'Critical Care',
#  'Diagnosis, Computer-Assisted',
#  'Electrocardiography',
#  'False Positive Reactions',
#  'Humans',
#  'Pattern Recognition, Automated',
#  'Reproducibility of Results',
#  'Sensitivity and Specificity',
#  'Aged',
#  'Aged, 80 and over',
#  'Antipyretics',
#  'Boston',
#  'Critical Illness',
#  'Female',
#  'Fever',
#  'Fever',
#  'Humans',
#  'Male',
#  'Middle Aged',
#  'Sepsis',
#  'Sepsis',
#  'Aged',
#  'Area Under Curve',
#  'Arterial Pressure',
#  'Bilirubin',
#  'Biomarkers',
#  'Creatinine',
#  'Critical Illness',
#  'Databases, Factual',
#  'Decision Support Techniques',
#  'Female',
#  'Humans',
#  'International Normalized Ratio',
#  'Kaplan-Meier Estimate',
#  'Liver Cirrhosis',
#  'Liver Cirrhosis',
#  'Liver Cirrhosis',
#  'Liver Cirrhosis',
#  'Liver Failure',
#  'Liver Failure',
#  'Liver Failure',
#  'Liver Failure',
#  'Male',
#  'Middle Aged',
#  'Models, Biological',
#  'Multiple Organ Failure',
#  'Multiple Organ Failure',
#  'Multiple Organ Failure',
#  'Multiple Organ Failure',
#  'Organ Dysfunction Scores',
#  'Predictive Value of Tests',
#  'Prognosis',
#  'ROC Curve',
#  'Reproducibility of Results',
#  'Risk Assessment',
#  'Risk Factors',
#  'Time Factors',
#  'Blood Glucose',
#  'Critical Illness',
#  'Critical Illness',
#  'Female',
#  'Humans',
#  'Hyperglycemia',
#  'Hypoglycemia',
#  'Male',
#  'Middle Aged',
#  'Organ Dysfunction Scores',
#  'Prognosis',
#  'Proportional Hazards Models',
#  'Reproducibility of Results',
#  'Severity of Illness Index',
#  'Arrhythmias, Cardiac',
#  'Arrhythmias, Cardiac',
#  'Clinical Alarms',
#  'Costs and Cost Analysis',
#  'Electrocardiography',
#  'False Positive Reactions',
#  'Heart Rate',
#  'Humans',
#  'Signal Processing, Computer-Assisted',
#  'Support Vector Machine',
#  'Time Factors',
#  'Adult',
#  'Alcoholism',
#  'Female',
#  'Humans',
#  'Male',
#  'Middle Aged',
#  'Models, Biological',
#  'Predictive Value of Tests',
#  'Software',
#  'Time Factors',
#  'Triage',
#  'Algorithms',
#  'Electronic Health Records',
#  'Humans',
#  'Models, Theoretical',
#  'Mortality',
#  'Time Factors',
#  'Algorithms',
#  'Cluster Analysis',
#  'Databases, Factual',
#  'Aged',
#  'Critical Illness',
#  'Female',
#  'Health Status Indicators',
#  'Humans',
#  'Liver Cirrhosis',
#  'Liver Cirrhosis',
#  'Male',
#  'Middle Aged',
#  'Prognosis',
#  'Respiratory Insufficiency',
#  'Respiratory Insufficiency',
#  'Retrospective Studies',
#  'Risk Assessment',
#  'Severity of Illness Index',
#  'Algorithms',
#  'Databases, Factual',
#  'Humans',
#  'Photoplethysmography',
#  'Signal Processing, Computer-Assisted',
#  'Ventricular Premature Complexes',
#  'Adult',
#  'Computational Biology',
#  'Databases, Factual',
#  'Hemodynamics',
#  'Humans',
#  'Models, Biological',
#  'Multivariate Analysis',
#  'Prognosis',
#  'Shock, Septic',
#  'Shock, Septic',
#  'Aged',
#  'Aged, 80 and over',
#  'Critical Care',
#  'Databases, Factual',
#  'Humans',
#  'Middle Aged',
#  'Mortality',
#  'Patient Discharge',
#  'Pattern Recognition, Automated',
#  'Prognosis',
#  'Algorithms',
#  'Blood Pressure',
#  'Electrocardiography',
#  'Heart Ventricles',
#  'Heart Ventricles',
#  'Hemodynamics',
#  'Humans',
#  'Monitoring, Physiologic',
#  'Tachycardia, Ventricular',
#  'Wavelet Analysis',
#  'Algorithms',
#  'Databases, Factual',
#  'Electronic Health Records',
#  'Female',
#  'Humans',
#  'Infant, Newborn',
#  'Massachusetts',
#  'Mothers',
#  'Pattern Recognition, Automated',
#  'Algorithms',
#  'Datasets as Topic',
#  'Electronic Health Records',
#  'Electronic Health Records',
#  'Health Information Exchange',
#  'Health Information Interoperability',
#  'Health Level Seven',
#  'Humans',
#  'Internet',
#  'Pilot Projects',
#  'Software',
#  'Algorithms',
#  'Databases, Factual',
#  'Dose-Response Relationship, Drug',
#  'Heparin',
#  'Heparin',
#  'Humans',
#  'Learning',
#  'Length of Stay',
#  'Markov Chains',
#  'Reinforcement (Psychology)',
#  'Retrospective Studies',
#  'Bayes Theorem',
#  'Data Mining',
#  'Humans',
#  'Knowledge Bases',
#  'Linguistics',
#  'Medical Informatics',
#  ...]

# %%
set(all_mesh_terms)
# Out:
# {'Academic Medical Centers',
#  'Access to Information',
#  'Acute Disease',
#  'Acute Kidney Injury',
#  'Adolescent',
#  'Adult',
#  'African Americans',
#  'Age Factors',
#  'Aged',
#  'Aged, 80 and over',
#  'Airway Extubation',
#  'Alanine Transaminase',
#  'Alcoholism',
#  'Algorithms',
#  'Anti-Bacterial Agents',
#  'Antipyretics',
#  'Area Under Curve',
#  'Arrhythmias, Cardiac',
#  'Arterial Pressure',
#  'Artifacts',
#  'Artificial Intelligence',
#  'Asian Americans',
#  'Bayes Theorem',
#  'Bilirubin',
#  'Biomarkers',
#  'Biomedical Engineering',
#  'Biomedical Research',
#  'Blood Glucose',
#  'Blood Pressure',
#  'Blood Pressure Determination',
#  'Body Mass Index',
#  'Body Temperature',
#  'Boston',
#  'Brain Injuries',
#  'Brain Ischemia',
#  'Calcium',
#  'Cardiology',
#  'Cell Count',
#  'Child',
#  'Child, Preschool',
#  'Circadian Rhythm',
#  'Classification',
#  'Clinical Alarms',
#  'Clinical Coding',
#  'Clinical Laboratory Techniques',
#  'Clostridium Infections',
#  'Clostridium difficile',
#  'Cluster Analysis',
#  'Cohort Studies',
#  'Comorbidity',
#  'Computational Biology',
#  'Computer Simulation',
#  'Continental Population Groups',
#  'Costs and Cost Analysis',
#  'Creatinine',
#  'Critical Care',
#  'Critical Illness',
#  'Cross Infection',
#  'Cross-Sectional Studies',
#  'Cryotherapy',
#  'Data Interpretation, Statistical',
#  'Data Mining',
#  'Database Management Systems',
#  'Databases, Factual',
#  'Datasets as Topic',
#  'Decision Making, Computer-Assisted',
#  'Decision Support Systems, Clinical',
#  'Decision Support Systems, Management',
#  'Decision Support Techniques',
#  'Decision Trees',
#  'Delayed Diagnosis',
#  'Demography',
#  'Diabetic Ketoacidosis',
#  'Diagnosis, Computer-Assisted',
#  'Diagnostic Errors',
#  'Disseminated Intravascular Coagulation',
#  'Dose-Response Relationship, Drug',
#  'Early Diagnosis',
#  'Electrocardiography',
#  'Electronic Data Processing',
#  'Electronic Health Records',
#  'Electronic Health Records*',
#  'Equipment Failure',
#  'Erythrocyte Indices',
#  'Erythrocyte Volume',
#  'European Continental Ancestry Group',
#  'Evaluation Studies as Topic',
#  'Expert Systems',
#  'False Positive Reactions',
#  'Female',
#  'Fever',
#  'Fluid Therapy',
#  'Forecasting',
#  'Fourier Analysis',
#  'Fuzzy Logic',
#  'Genomics',
#  'Health Information Exchange',
#  'Health Information Interoperability',
#  'Health Level Seven',
#  'Health Status',
#  'Health Status Disparities',
#  'Health Status Indicators',
#  'Heart',
#  'Heart Failure',
#  'Heart Function Tests',
#  'Heart Rate',
#  'Heart Ventricles',
#  'Hemodynamics',
#  'Heparin',
#  'Hepatitis',
#  'Hospital Mortality',
#  'Humans',
#  'Hyperglycemia',
#  'Hyperlactatemia',
#  'Hypoglycemia',
#  'Hypotension',
#  'Hypovolemia',
#  'Hypoxia',
#  'Iatrogenic Disease',
#  'Incidence',
#  'Infant',
#  'Infant, Newborn',
#  'Information Storage and Retrieval',
#  'Information Systems',
#  'Information Theory',
#  'Intensive Care Units',
#  'Intensive Care Units*',
#  'Intensive Care Units, Pediatric',
#  'International Classification of Diseases',
#  'International Normalized Ratio',
#  'Internet',
#  'Intubation',
#  'Isotonic Solutions',
#  'Jaundice, Neonatal',
#  'Kaplan-Meier Estimate',
#  'Knowledge Bases',
#  'L-Lactate Dehydrogenase',
#  'Learning',
#  'Least-Squares Analysis',
#  'Length of Stay',
#  'Leukocyte Count',
#  'Leukocytosis',
#  'Linear Models',
#  'Linguistics',
#  'Liver Cirrhosis',
#  'Liver Failure',
#  'Logistic Models',
#  'Longitudinal Studies',
#  'Lymphocyte Count',
#  'Lymphocytes',
#  'Machine Learning',
#  'Male',
#  'Markov Chains',
#  'Massachusetts',
#  'Medical Informatics',
#  'Medical Informatics Applications',
#  'Medical Records',
#  'Medical Records Systems, Computerized',
#  'Middle Aged',
#  'Models, Biological',
#  'Models, Cardiovascular',
#  'Models, Statistical',
#  'Models, Theoretical',
#  'Monitoring, Ambulatory',
#  'Monitoring, Physiologic',
#  'Mortality',
#  'Mothers',
#  'Multiple Myeloma',
#  'Multiple Organ Failure',
#  'Multivariate Analysis',
#  'Natural Language Processing',
#  'Neural Networks (Computer)',
#  'Neutrophils',
#  'New York',
#  'Nonlinear Dynamics',
#  'Norepinephrine',
#  'Nurses',
#  'Nursing Records',
#  'Obesity',
#  'Organ Dysfunction Scores',
#  'Outcome Assessment (Health Care)',
#  'Overweight',
#  'Oxygen',
#  'Pancreatitis',
#  'Partial Pressure',
#  'Patient Admission',
#  'Patient Discharge',
#  'Patient Readmission',
#  'Patient-Specific Modeling',
#  'Pattern Recognition, Automated',
#  'Phenotype',
#  'Photoplethysmography',
#  'Phototherapy',
#  'Pilot Projects',
#  'Platelet Count',
#  'Plethysmography',
#  'Postoperative Complications',
#  'Predictive Value of Tests',
#  'Pressure',
#  'Principal Component Analysis',
#  'Probability',
#  'Prognosis',
#  'Programming Languages',
#  'Proportional Hazards Models',
#  'Prospective Studies',
#  'Quality Assurance, Health Care',
#  'Quality Control',
#  'ROC Curve',
#  'Reference Values',
#  'Regression Analysis',
#  'Reinforcement (Psychology)',
#  'Reproducibility of Results',
#  'Research',
#  'Respiration Disorders',
#  'Respiration, Artificial',
#  'Respiratory Distress Syndrome, Adult',
#  'Respiratory Distress Syndrome, Newborn',
#  'Respiratory Insufficiency',
#  'Respiratory Rate',
#  'Resuscitation',
#  'Retrospective Studies',
#  "Ringer's Lactate",
#  'Risk',
#  'Risk Assessment',
#  'Risk Factors',
#  'Sensitivity and Specificity',
#  'Sepsis',
#  'Serotonin Uptake Inhibitors',
#  'Severity of Illness Index',
#  'Shock, Septic',
#  'Signal Processing, Computer-Assisted',
#  'Sodium Chloride',
#  'Software',
#  'Stroke Volume',
#  'Subarachnoid Hemorrhage',
#  'Supervised Machine Learning',
#  'Support Vector Machine',
#  'Survival Analysis',
#  'Systematized Nomenclature of Medicine',
#  'Tachycardia, Ventricular',
#  'Terminology as Topic',
#  'Tertiary Care Centers',
#  'Therapeutics',
#  'Tilt-Table Test',
#  'Time',
#  'Time Factors',
#  'Treatment Failure',
#  'Triage',
#  'Unified Medical Language System',
#  'United Kingdom',
#  'United States',
#  'Unnecessary Procedures',
#  'Unsupervised Machine Learning',
#  'User-Computer Interface',
#  'Vasoconstrictor Agents',
#  'Vasoconstrictor Agents*',
#  'Ventricular Function, Left',
#  'Ventricular Premature Complexes',
#  'Vital Signs',
#  'Wavelet Analysis',
#  'Young Adult'}

# %%
# Get the counts, and count percentages (divided by number of papers)
counts = []

for term in set(all_mesh_terms):
    wc = all_mesh_terms.count(term)
    counts.append([wc, math.ceil(wc / len(titles) * 100), term])
    
counts.sort(reverse=True)

# %%
counts
# Out:
# [[85, 68, 'Humans'],
#  [46, 37, 'Intensive Care Units'],
#  [37, 30, 'Databases, Factual'],
#  [32, 26, 'Algorithms'],
#  [27, 22, 'Female'],
#  [26, 21, 'Critical Care'],
#  [25, 20, 'Male'],
#  [24, 20, 'Middle Aged'],
#  [21, 17, 'Aged'],
#  [21, 17, 'Adult'],
#  [17, 14, 'Prognosis'],
#  [17, 14, 'Electronic Health Records'],
#  [16, 13, 'Retrospective Studies'],
#  [16, 13, 'Critical Illness'],
#  [15, 12, 'Reproducibility of Results'],
#  [14, 12, 'Sepsis'],
#  [11, 9, 'Monitoring, Physiologic'],
#  [11, 9, 'Hypotension'],
#  [11, 9, 'Hospital Mortality'],
#  [10, 8, 'Sensitivity and Specificity'],
#  [10, 8, 'Risk Assessment'],
#  [9, 8, 'Time Factors'],
#  [9, 8, 'Software'],
#  [9, 8, 'Signal Processing, Computer-Assisted'],
#  [9, 8, 'ROC Curve'],
#  [9, 8, 'Blood Pressure'],
#  [8, 7, 'Severity of Illness Index'],
#  [8, 7, 'Multiple Organ Failure'],
#  [8, 7, 'Data Mining'],
#  [8, 7, 'Aged, 80 and over'],
#  [7, 6, 'Risk Factors'],
#  [7, 6, 'Regression Analysis'],
#  [7, 6, 'Predictive Value of Tests'],
#  [7, 6, 'Pattern Recognition, Automated'],
#  [7, 6, 'Medical Informatics'],
#  [7, 6, 'Information Storage and Retrieval'],
#  [7, 6, 'Heart Rate'],
#  [6, 5, 'Liver Cirrhosis'],
#  [6, 5, 'Electrocardiography'],
#  [6, 5, 'Diagnosis, Computer-Assisted'],
#  [6, 5, 'Boston'],
#  [5, 4, 'Support Vector Machine'],
#  [5, 4, 'Pancreatitis'],
#  [5, 4, 'Models, Theoretical'],
#  [5, 4, 'Machine Learning'],
#  [5, 4, 'Logistic Models'],
#  [5, 4, 'Hemodynamics'],
#  [5, 4, 'Decision Support Systems, Clinical'],
#  [5, 4, 'Artificial Intelligence'],
#  [5, 4, 'Acute Disease'],
#  [4, 4, 'Vasoconstrictor Agents'],
#  [4, 4, 'Subarachnoid Hemorrhage'],
#  [4, 4, 'Shock, Septic'],
#  [4, 4, 'Respiration, Artificial'],
#  [4, 4, 'Respiration Disorders'],
#  [4, 4, 'Phenotype'],
#  [4, 4, 'Multivariate Analysis'],
#  [4, 4, 'Models, Biological'],
#  [4, 4, 'Liver Failure'],
#  [4, 4, 'Internet'],
#  [4, 4, 'International Classification of Diseases'],
#  [4, 4, 'False Positive Reactions'],
#  [4, 4, 'Acute Kidney Injury'],
#  [3, 3, 'Wavelet Analysis'],
#  [3, 3, 'User-Computer Interface'],
#  [3, 3, 'Respiratory Rate'],
#  [3, 3, 'Respiratory Distress Syndrome, Newborn'],
#  [3, 3, 'Patient Readmission'],
#  [3, 3, 'Patient Discharge'],
#  [3, 3, 'Patient Admission'],
#  [3, 3, 'Organ Dysfunction Scores'],
#  [3, 3, 'Neural Networks (Computer)'],
#  [3, 3, 'Natural Language Processing'],
#  [3, 3, 'Multiple Myeloma'],
#  [3, 3, 'Models, Statistical'],
#  [3, 3, 'Medical Records Systems, Computerized'],
#  [3, 3, 'Medical Informatics Applications'],
#  [3, 3, 'Length of Stay'],
#  [3, 3, 'Infant, Newborn'],
#  [3, 3, 'Hypoxia'],
#  [3, 3, 'Hepatitis'],
#  [3, 3, 'Heart Failure'],
#  [3, 3, 'Computational Biology'],
#  [3, 3, 'Biomarkers'],
#  [3, 3, 'Arrhythmias, Cardiac'],
#  [3, 3, 'Area Under Curve'],
#  [3, 3, 'Antipyretics'],
#  [3, 3, 'Access to Information'],
#  [2, 2, 'Young Adult'],
#  [2, 2, 'Vital Signs'],
#  [2, 2, 'Unified Medical Language System'],
#  [2, 2, 'Triage'],
#  [2, 2, 'Therapeutics'],
#  [2, 2, 'Tachycardia, Ventricular'],
#  [2, 2, 'Risk'],
#  [2, 2, 'Resuscitation'],
#  [2, 2, 'Respiratory Insufficiency'],
#  [2, 2, 'Respiratory Distress Syndrome, Adult'],
#  [2, 2, 'Proportional Hazards Models'],
#  [2, 2, 'Probability'],
#  [2, 2, 'Postoperative Complications'],
#  [2, 2, 'Pilot Projects'],
#  [2, 2, 'Photoplethysmography'],
#  [2, 2, 'Overweight'],
#  [2, 2, 'Obesity'],
#  [2, 2, 'Nurses'],
#  [2, 2, 'New York'],
#  [2, 2, 'Mortality'],
#  [2, 2, 'Massachusetts'],
#  [2, 2, 'Markov Chains'],
#  [2, 2, 'Linear Models'],
#  [2, 2, 'Kaplan-Meier Estimate'],
#  [2, 2, 'Jaundice, Neonatal'],
#  [2, 2, 'Heparin'],
#  [2, 2, 'Heart Ventricles'],
#  [2, 2, 'Health Status Indicators'],
#  [2, 2, 'Fuzzy Logic'],
#  [2, 2, 'Fever'],
#  [2, 2, 'Expert Systems'],
#  [2, 2, 'Diabetic Ketoacidosis'],
#  [2, 2, 'Decision Support Techniques'],
#  [2, 2, 'Decision Making, Computer-Assisted'],
#  [2, 2, 'Datasets as Topic'],
#  [2, 2, 'Computer Simulation'],
#  [2, 2, 'Clostridium Infections'],
#  [2, 2, 'Clinical Alarms'],
#  [2, 2, 'Child'],
#  [2, 2, 'Calcium'],
#  [2, 2, 'Body Temperature'],
#  [2, 2, 'Blood Pressure Determination'],
#  [2, 2, 'Biomedical Research'],
#  [2, 2, 'Bilirubin'],
#  [1, 1, 'Ventricular Premature Complexes'],
#  [1, 1, 'Ventricular Function, Left'],
#  [1, 1, 'Unsupervised Machine Learning'],
#  [1, 1, 'Unnecessary Procedures'],
#  [1, 1, 'United States'],
#  [1, 1, 'United Kingdom'],
#  [1, 1, 'Treatment Failure'],
#  [1, 1, 'Time'],
#  [1, 1, 'Tilt-Table Test'],
#  [1, 1, 'Tertiary Care Centers'],
#  [1, 1, 'Terminology as Topic'],
#  [1, 1, 'Systematized Nomenclature of Medicine'],
#  [1, 1, 'Survival Analysis'],
#  [1, 1, 'Supervised Machine Learning'],
#  [1, 1, 'Stroke Volume'],
#  [1, 1, 'Sodium Chloride'],
#  [1, 1, 'Serotonin Uptake Inhibitors'],
#  [1, 1, "Ringer's Lactate"],
#  [1, 1, 'Research'],
#  [1, 1, 'Reinforcement (Psychology)'],
#  [1, 1, 'Reference Values'],
#  [1, 1, 'Quality Control'],
#  [1, 1, 'Quality Assurance, Health Care'],
#  [1, 1, 'Prospective Studies'],
#  [1, 1, 'Programming Languages'],
#  [1, 1, 'Principal Component Analysis'],
#  [1, 1, 'Pressure'],
#  [1, 1, 'Plethysmography'],
#  [1, 1, 'Platelet Count'],
#  [1, 1, 'Phototherapy'],
#  [1, 1, 'Patient-Specific Modeling'],
#  [1, 1, 'Partial Pressure'],
#  [1, 1, 'Oxygen'],
#  [1, 1, 'Outcome Assessment (Health Care)'],
#  [1, 1, 'Nursing Records'],
#  [1, 1, 'Norepinephrine'],
#  [1, 1, 'Nonlinear Dynamics'],
#  [1, 1, 'Neutrophils'],
#  [1, 1, 'Mothers'],
#  [1, 1, 'Monitoring, Ambulatory'],
#  [1, 1, 'Models, Cardiovascular'],
#  [1, 1, 'Medical Records'],
#  [1, 1, 'Lymphocytes'],
#  [1, 1, 'Lymphocyte Count'],
#  [1, 1, 'Longitudinal Studies'],
#  [1, 1, 'Linguistics'],
#  [1, 1, 'Leukocytosis'],
#  [1, 1, 'Leukocyte Count'],
#  [1, 1, 'Least-Squares Analysis'],
#  [1, 1, 'Learning'],
#  [1, 1, 'L-Lactate Dehydrogenase'],
#  [1, 1, 'Knowledge Bases'],
#  [1, 1, 'Isotonic Solutions'],
#  [1, 1, 'Intubation'],
#  [1, 1, 'International Normalized Ratio'],
#  [1, 1, 'Intensive Care Units, Pediatric'],
#  [1, 1, 'Information Theory'],
#  [1, 1, 'Information Systems'],
#  [1, 1, 'Infant'],
#  [1, 1, 'Incidence'],
#  [1, 1, 'Iatrogenic Disease'],
#  [1, 1, 'Hypovolemia'],
#  [1, 1, 'Hypoglycemia'],
#  [1, 1, 'Hyperlactatemia'],
#  [1, 1, 'Hyperglycemia'],
#  [1, 1, 'Heart Function Tests'],
#  [1, 1, 'Heart'],
#  [1, 1, 'Health Status Disparities'],
#  [1, 1, 'Health Status'],
#  [1, 1, 'Health Level Seven'],
#  [1, 1, 'Health Information Interoperability'],
#  [1, 1, 'Health Information Exchange'],
#  [1, 1, 'Genomics'],
#  [1, 1, 'Fourier Analysis'],
#  [1, 1, 'Forecasting'],
#  [1, 1, 'Fluid Therapy'],
#  [1, 1, 'Evaluation Studies as Topic'],
#  [1, 1, 'European Continental Ancestry Group'],
#  [1, 1, 'Erythrocyte Volume'],
#  [1, 1, 'Erythrocyte Indices'],
#  [1, 1, 'Equipment Failure'],
#  [1, 1, 'Electronic Data Processing'],
#  [1, 1, 'Early Diagnosis'],
#  [1, 1, 'Dose-Response Relationship, Drug'],
#  [1, 1, 'Disseminated Intravascular Coagulation'],
#  [1, 1, 'Diagnostic Errors'],
#  [1, 1, 'Demography'],
#  [1, 1, 'Delayed Diagnosis'],
#  [1, 1, 'Decision Trees'],
#  [1, 1, 'Decision Support Systems, Management'],
#  [1, 1, 'Database Management Systems'],
#  [1, 1, 'Data Interpretation, Statistical'],
#  [1, 1, 'Cryotherapy'],
#  [1, 1, 'Cross-Sectional Studies'],
#  [1, 1, 'Cross Infection'],
#  [1, 1, 'Creatinine'],
#  [1, 1, 'Costs and Cost Analysis'],
#  [1, 1, 'Continental Population Groups'],
#  [1, 1, 'Comorbidity'],
#  [1, 1, 'Cohort Studies'],
#  [1, 1, 'Cluster Analysis'],
#  [1, 1, 'Clostridium difficile'],
#  [1, 1, 'Clinical Laboratory Techniques'],
#  [1, 1, 'Clinical Coding'],
#  [1, 1, 'Classification'],
#  [1, 1, 'Circadian Rhythm'],
#  [1, 1, 'Child, Preschool'],
#  [1, 1, 'Cell Count'],
#  [1, 1, 'Cardiology'],
#  [1, 1, 'Brain Ischemia'],
#  [1, 1, 'Brain Injuries'],
#  [1, 1, 'Body Mass Index'],
#  [1, 1, 'Blood Glucose'],
#  [1, 1, 'Biomedical Engineering'],
#  [1, 1, 'Bayes Theorem'],
#  [1, 1, 'Asian Americans'],
#  [1, 1, 'Artifacts'],
#  [1, 1, 'Arterial Pressure'],
#  [1, 1, 'Anti-Bacterial Agents'],
#  [1, 1, 'Alcoholism'],
#  [1, 1, 'Alanine Transaminase'],
#  [1, 1, 'Airway Extubation'],
#  [1, 1, 'Age Factors'],
#  [1, 1, 'African Americans'],
#  [1, 1, 'Adolescent'],
#  [1, 1, 'Academic Medical Centers']]

# %%
# Write results to pipe delimited file.
with open('/home/cx1111/Projects/citation-tracker/search_results/pubmed/mesh-counts.csv', 'w') as f:
    f.write('term|count_percentage\n')
    for count, pcount, word in counts:
        f.write('|'.join([word, str(pcount)]) + '\n')

# %%
# Organize the publication types
pub_counts = []

for term in set(all_publication_types):
    wc = all_publication_types.count(term)
    pub_counts.append([wc, math.ceil(wc / len(titles) * 100), term])    

# There is also the unspecified category
wc = len(titles) - len(all_publication_types)
pub_counts.append([wc, math.ceil(wc / len(titles) * 100), 'Unspecified'])

pub_counts.sort(reverse=True)

# %%
pub_counts
# Out:
# [[78, 63, 'Unspecified'],
#  [19, 16, 'Research Support, N.I.H., Extramural'],
#  [15, 12, "Research Support, Non-U.S. Gov't"],
#  [6, 5, 'Comparative Study'],
#  [3, 3, 'Research Support, N.I.H., Intramural'],
#  [2, 2, "Research Support, U.S. Gov't, Non-P.H.S."],
#  [1, 1, 'Observational Study'],
#  [1, 1, 'Evaluation Studies']]

# %%
plt.figure()
country.max().sort_values(by="points",ascending=False)["points"].plot.bar()
plt.xticks(rotation=50)
plt.xlabel("Country of Origin")
plt.ylabel("Highest point of Wines")
plt.show()

# %%
# Bar graph of publication types
x = range(len(pub_counts))
plt.figure()
plt.bar(x, [p[1] for p in pub_counts])
# Strip the long labels on the x axis
plt.xticks(x, [p[2].strip('Research Support, ') for p in pub_counts])
plt.title('Publication Types')
plt.xlabel('Category')
plt.ylabel('Percentage')
plt.show()

# %%
# Bar graph of publication types, excluding unspecified
scale_factor = sum(p[1] for p in pub_counts) /  sum(p[1] for p in pub_counts[1:])
x = range(len(pub_counts)-1)
plt.figure()
plt.bar(x, [p[1]*scale_factor for p in pub_counts[1:]])
# Strip the long labels on the x axis
plt.xticks(x, [p[2].strip('Research Support, ') for p in pub_counts[1:]])
plt.title('Publication Types (excluding unspecified)')
plt.xlabel('Category')
plt.ylabel('Percentage')
plt.show()

# %%
pub_counts
# Out:
# [[78, 63, 'Unspecified'],
#  [19, 16, 'Research Support, N.I.H., Extramural'],
#  [15, 12, "Research Support, Non-U.S. Gov't"],
#  [6, 5, 'Comparative Study'],
#  [3, 3, 'Research Support, N.I.H., Intramural'],
#  [2, 2, "Research Support, U.S. Gov't, Non-P.H.S."],
#  [1, 1, 'Observational Study'],
#  [1, 1, 'Evaluation Studies']]

# %%
# Write results to pipe delimited file.
with open('/home/cx1111/Projects/citation-tracker/search_results/pubmed/publication-types.csv', 'w') as f:
    f.write('publication_type|count_percentage|count_percentage_excluding_unspecified\n')
    for count, pcount, ptype in pub_counts:
        if ptype == 'Unspecified':
            f.write('|'.join([ptype, str(pcount), '0']) + '\n')
        else:
            f.write('|'.join([ptype, str(pcount), str(math.ceil(pcount * scale_factor))]) + '\n')
